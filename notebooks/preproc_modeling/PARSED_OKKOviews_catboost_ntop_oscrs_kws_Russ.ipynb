# %%
# !pip install scikit-optimize
# !pip install statsmodels
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting scikit-optimize
#   Downloading scikit_optimize-0.9.0-py2.py3-none-any.whl (100 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.3/100.3 kB 2.2 MB/s eta 0:00:00
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.9/dist-packages (from scikit-optimize) (1.2.2)
# Collecting pyaml>=16.9
#   Downloading pyaml-21.10.1-py2.py3-none-any.whl (24 kB)
# Requirement already satisfied: scipy>=0.19.1 in /usr/local/lib/python3.9/dist-packages (from scikit-optimize) (1.10.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.9/dist-packages (from scikit-optimize) (1.1.1)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.9/dist-packages (from scikit-optimize) (1.22.4)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.9/dist-packages (from pyaml>=16.9->scikit-optimize) (6.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn>=0.20.0->scikit-optimize) (3.1.0)
# Installing collected packages: pyaml, scikit-optimize
# Successfully installed pyaml-21.10.1 scikit-optimize-0.9.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.9/dist-packages (0.13.5)
# Requirement already satisfied: scipy>=1.3 in /usr/local/lib/python3.9/dist-packages (from statsmodels) (1.10.1)
# Requirement already satisfied: pandas>=0.25 in /usr/local/lib/python3.9/dist-packages (from statsmodels) (1.4.4)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.9/dist-packages (from statsmodels) (23.0)
# Requirement already satisfied: patsy>=0.5.2 in /usr/local/lib/python3.9/dist-packages (from statsmodels) (0.5.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.9/dist-packages (from statsmodels) (1.22.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=0.25->statsmodels) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=0.25->statsmodels) (2022.7.1)
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from patsy>=0.5.2->statsmodels) (1.16.0)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from collections import Counter

import statsmodels.stats.api as sms
from matplotlib import style
style.use('seaborn')
# %matplotlib inline
#graphs in svg look clearer
# %config InlineBackend.figure_format = 'svg'
# Out:
# <ipython-input-2-b46d91121558>:9: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   style.use('seaborn')

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Functions

# %%
from sklearn import metrics

def mae(y_gt, Y_pr):
    return metrics.mean_absolute_error(y_gt, Y_pr)

def mse(y_gt, Y_pr):
    return metrics.mean_squared_error(y_gt, Y_pr)

def rmse(y_gt, Y_pr):
    my_mse = mse(y_gt, Y_pr)
    return np.sqrt(my_mse)

def medae(y_gt, Y_pr):
    return metrics.median_absolute_error(y_gt, Y_pr)

def R2(y_gt, Y_pr):
    return metrics.r2_score(y_gt, Y_pr)

def calc_metrics(true, pred):

    mse1 = mse(true, pred)

    rmse1 = rmse(true, pred)

    mae1 = mae(true, pred)

    medae1 = medae(true, pred)

    R21 = R2(true, pred)

    print('*** VAL **: ')
    print("MSE:   {}\nRMSE:  {}\nR2:    {}\nMAE:   {}\nMedAE: {}".format(mse1, rmse1, R21, mae1, medae1))
    print('-'*30)

# %%
def target_distr_linear(train_label, test_label, predicted_dv): 
    sns.kdeplot(train_label, label='train')
    sns.kdeplot(test_label, label='test')
    sns.kdeplot(predicted_dv, label='pred')
    plt.legend()
    plt.show()

    ddd = pd.DataFrame({'test_lbl': test_label, 'pred_lbl':predicted_dv})
    sns.scatterplot(ddd, x='test_lbl', y='pred_lbl', color='blueviolet')
    plt.title('Linear model')
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.show()

# %%
from scipy.stats import norm

def draw_histogram(data):
    f,ax_hist = plt.subplots(1)
    sns.distplot(data, hist=True,  kde=True, rug=True, bins=10, fit=norm, ax=ax_hist);
    plt.xlabel("values")
    plt.title("Distribution") 

    mean=data.mean()

    ax_hist.axvline(mean, color='r', linestyle='--', label=f"Mean={mean:.3f}")
    ax_hist.legend()

    plt.show()

# %%
def draw_res_analys(errors, pred):
    sns.scatterplot(list(range(len(errors))),errors);
    plt.title("Distibution of errors")
    plt.ylabel('Error');
    plt.xlabel('Index');
    plt.show();

    sns.scatterplot(pred,errors);
    plt.title('Relationship of true value vs error (resudual analysis)')
    plt.ylabel('Error');
    plt.xlabel('True value');
    plt.show();

# %%
def get_feature_imp(model, X_train):
    imp = model.get_feature_importance(data=X_train)
    fig, axes = plt.subplots(1, 1, figsize=(12, 8))
    axes.barh(width=imp, y=model.feature_names_)
    axes.set_title('Finetuned Catboost feature importance')
    plt.show()

# %% [markdown]
# ### Load df

# %%
import pickle

with open('/content/drive/My Drive/Diploma/CODE/Okko_ratings_RUSS.pkl', 'rb') as f:
    df = pickle.load(f, encoding='utf-8')

# %%
with open('/content/drive/My Drive/Diploma/CODE/watches_target_dataset.pkl', 'rb') as f:
    df_target = pickle.load(f, encoding='utf-8')

# %%
df_target = df_target[['uid', 'target']]

# %%
df_target.rename(columns={'uid': 'element_uid'}, inplace=True)

# %%
df_target.shape, df.shape
# Out:
# ((11666, 2), (1705, 1027))

# %%
df = df.merge(df_target, on='element_uid')

# %%
df.shape
# Out:
# (837, 1028)

# %%
df.columns[-30:]
# Out:
# Index(['ханна', 'отпор', 'воришка', 'одри', 'деспотичный', 'хэл', 'шоубизнес',
#        'провоцировать', 'селин', 'уолтер', 'непобедимый', 'молль', 'небывалый',
#        'ларри', 'харпер', 'прихожанин', 'спецподразделение', 'сущий', 'пята',
#        'вылечивать', 'землянин', 'рон', 'головоломка', 'крюк', 'чета', 'зебра',
#        'сидень', 'беатрис', 'рыбка', 'target'],
#       dtype='object')

# %% [markdown]
# # Preprocessing

# %%
prep_df = df.copy(deep=True)

# %%
prep_df.shape
# Out:
# (837, 1028)

# %%
prep_df.isna().sum()
# Out:
# age_access_type     0
# name                0
# director            0
# genre               0
# average_rating     24
#                    ..
# зебра               0
# сидень              0
# беатрис             0
# рыбка               0
# target              0
# Length: 1028, dtype: int64

# %% [markdown]
# ### filter by year

# %%
prep_df = prep_df[prep_df['release_year'] >= 2000]

# %%
prep_df.shape
# Out:
# (807, 1028)

# %%
prep_df.isna().sum()
# Out:
# age_access_type     0
# name                0
# director            0
# genre               0
# average_rating     24
#                    ..
# зебра               0
# сидень              0
# беатрис             0
# рыбка               0
# target              0
# Length: 1028, dtype: int64

# %% [markdown]
# ### topN

# %%
# import ast

# columns = ['ACTOR', 'COMPOSER', 'DESIGN', 'DIRECTOR', 'EDITOR',
#                       'OPERATOR', 'PRODUCER', 'WRITER', 'country', 'genre']
# for col in columns:
#     prep_df[col] = prep_df[col].apply(lambda x: ast.literal_eval(x) if not isinstance(x, float) else np.nan)

prep_df.dropna(subset=['ACTOR', 'COMPOSER', 'DESIGN', 'DIRECTOR', 'EDITOR', 'OPERATOR', 'PRODUCER', 'WRITER'],
              inplace=True)

# %%
prep_df.shape
# Out:
# (411, 1028)

# %%
prep_df.isna().sum()
# Out:
# age_access_type    0
# name               0
# director           0
# genre              0
# average_rating     7
#                   ..
# зебра              0
# сидень             0
# беатрис            0
# рыбка              0
# target             0
# Length: 1028, dtype: int64

# %%
def add_topN_feature(df, col, n: int):
    items = []
    
    for i in df[col]:
        items.extend(i)

    topN = [x[0] for x in Counter(items).most_common()][:n]

    df[f'top{n}{col}'] = df[col].apply(lambda x: [int(item in x) for item in topN])
    df.drop(col, axis=1, inplace=True)
    return topN, f'top{n}{col}'

# %%
def ohe_topN_features(df, topN, cat):
    for i in range(len(topN)):
        df[f'{topN[i]}'] = [item[i] for item in df[cat]]
    df.drop(cat, axis=1, inplace=True)
    return df

# %%
prep_df.columns
# Out:
# Index(['age_access_type', 'name', 'director', 'genre', 'average_rating',
#        'type', 'country', 'release_type', 'release_year', 'duration',
#        ...
#        'землянин', 'рон', 'головоломка', 'крюк', 'чета', 'зебра', 'сидень',
#        'беатрис', 'рыбка', 'target'],
#       dtype='object', length=1028)

# %%
top10genres, name = add_topN_feature(prep_df, 'genre', 10)
prep_df = ohe_topN_features(prep_df, top10genres, name)

top5countries, name = add_topN_feature(prep_df, 'country', 5)
prep_df = ohe_topN_features(prep_df, top5countries, name)

top10actors, name = add_topN_feature(prep_df, 'ACTOR', 10)
prep_df = ohe_topN_features(prep_df, top10actors, name)

top3directors, name = add_topN_feature(prep_df, 'COMPOSER', 3)
prep_df = ohe_topN_features(prep_df, top3directors, name)

top2DESIGN, name = add_topN_feature(prep_df, 'DESIGN', 2)
prep_df = ohe_topN_features(prep_df, top2DESIGN, name)

top2DIRECTOR, name = add_topN_feature(prep_df, 'DIRECTOR', 2)
prep_df = ohe_topN_features(prep_df, top2DIRECTOR, name)

top2EDITOR, name = add_topN_feature(prep_df, 'EDITOR', 2)
prep_df = ohe_topN_features(prep_df, top2EDITOR, name)

top2OPERATOR, name = add_topN_feature(prep_df, 'OPERATOR', 2)
prep_df = ohe_topN_features(prep_df, top2OPERATOR, name)

top3PRODUCER, name = add_topN_feature(prep_df, 'PRODUCER', 3)
prep_df = ohe_topN_features(prep_df, top3PRODUCER, name)

top2WRITER, name = add_topN_feature(prep_df, 'WRITER', 2)
prep_df = ohe_topN_features(prep_df, top2WRITER, name)

# %%
prep_df.head().T
# Out:
#                                                          1  \
# age_access_type                                         16
# name                                      Медвежий поцелуй
# director            [3d64928e-b4a3-4c78-b176-77ef1045d5bc]
# average_rating                                        7.43
# type                                                 MOVIE
# ...                                                    ...
# Сергей Сельянов                                          1
# Георгий Малков                                           0
# Тимур Бекмамбетов                                        0
# Роман Непомнящий                                         0
# Александр Боярский                                       0
#
#                                                          2  \
# age_access_type                                         16
# name                                              Байконур
# director            [1f007e2b-31c6-4f3d-849c-95a1df635ab1]
# average_rating                                        6.09
# type                                                 MOVIE
# ...                                                    ...
# Сергей Сельянов                                          1
# Георгий Малков                                           0
# Тимур Бекмамбетов                                        0
# Роман Непомнящий                                         0
# Александр Боярский                                       0
#
#                                                          4  \
# age_access_type                                         16
# name                                                Монгол
# director            [3d64928e-b4a3-4c78-b176-77ef1045d5bc]
# average_rating                                        6.97
# type                                                 MOVIE
# ...                                                    ...
# Сергей Сельянов                                          1
# Георгий Малков                                           0
# Тимур Бекмамбетов                                        0
# Роман Непомнящий                                         0
# Александр Боярский                                       0
#
#                                                          5  \
# age_access_type                                         18
# name                                          Красный змей
# director            [622415d8-8c67-495b-acbd-06d04daeec26]
# average_rating                                        1.37
# type                                                 MOVIE
# ...                                                    ...
# Сергей Сельянов                                          0
# Георгий Малков                                           0
# Тимур Бекмамбетов                                        0
# Роман Непомнящий                                         0
# Александр Боярский                                       0
#
#                                                          6
# age_access_type                                         16
# name                                               Олигарх
# director            [c75aa66a-5ce5-4ec9-85e5-072df00d4ad7]
# average_rating                                         7.4
# type                                                 MOVIE
# ...                                                    ...
# Сергей Сельянов                                          1
# Георгий Малков                                           0
# Тимур Бекмамбетов                                        0
# Роман Непомнящий                                         0
# Александр Боярский                                       0
#
# [1059 rows x 5 columns]

# %%
prep_df.columns
# Out:
# Index(['age_access_type', 'name', 'director', 'average_rating', 'type',
#        'release_type', 'release_year', 'duration', 'actor', 'element_uid',
#        ...
#        'Алексей Балабанов', 'Александр Амиров', 'Сергей Иванов',
#        'Сергей Трофимов', 'Максим Осадчий', 'Сергей Сельянов',
#        'Георгий Малков', 'Тимур Бекмамбетов', 'Роман Непомнящий',
#        'Александр Боярский'],
#       dtype='object', length=1059)

# %%
prep_df.columns[:30]
# Out:
# Index(['age_access_type', 'name', 'director', 'average_rating', 'type',
#        'release_type', 'release_year', 'duration', 'actor', 'element_uid',
#        'BUDGET', 'MARKETING', 'RUS', 'USA', 'WORLD', 'element_id', 'rating',
#        'джек', 'расследовать', 'подруга', 'ограбление', 'катя', 'макс',
#        'мечтать', 'отважный', 'фрэнк', 'воспитывать', 'супергерой',
#        'безжалостный', 'маньяк'],
#       dtype='object')

# %%
prep_df.drop(['director', 'average_rating', 'release_type', 'actor', 'element_id', 'rating'], axis=1, inplace=True)

# %%
skewed_num_features = ['duration', 'BUDGET', 'MARKETING', 'RUS', 'USA', 'WORLD']

# %%
from collections import Counter
from sklearn.feature_extraction.text import TfidfVectorizer
import numpy as np
from sklearn.model_selection import train_test_split
import pandas as pd

class Preprocesser:
    def __init__(self, 
#                 mulpiple_cat_features: list,
                skewed_num_features: list,
               # text_features: list,
               # release_year_feature: str,
#                 mltpl_cat_n_top: dict
                ):
#         self.mulpiple_cat_features = mulpiple_cat_features
        self.skewed_num_features = skewed_num_features
        #self.text_features = text_features
#         self.mltpl_cat_n_top = mltpl_cat_n_top
       # self.release_year_feature = release_year_feature
        # self.tokenizer = Tokenizer(nlp.vocab)
        
    def __get_top_n_mltpl_cat_features(self, df_pr, col):
        all_cats = []
        for element_values in df_pr[col]:
            all_cats.extend(element_values)
        return Counter(all_cats).most_common(self.mltpl_cat_n_top[col])
            
    def __preprocess_mulpiple_cat_features(self, df_pr):
        for col in self.mulpiple_cat_features:
            feature_number = self.mltpl_cat_n_top[col]
            df_pr[[f'{col}_{i}' for i in range(feature_number)]] = pd.DataFrame(np.full((len(df), feature_number), np.nan))
            for i in df_pr.index:
                names = df_pr.loc[i, col]
                for k, name in enumerate(names[:int(feature_number)]):
                    df_pr.loc[i, f'{col}_{k}'] = name
            df_pr.drop(col, axis=1, inplace=True)

        return df_pr
    
    def __preprocess_skewed_num_features(self, df_pr):
        for col in self.skewed_num_features:
            df_pr[col] = df_pr[col].apply(lambda x: np.log1p(x))
        return df_pr
    
    def __preprocess_text_features(self, df_pr):
        for col in self.text_features:
            df_pr[col] = df_pr[col].apply(lambda x: self.tokenizer(x))
        return df_pr
            
    def preprocess(self,
                   df: pd.DataFrame):
        df_pr = df.copy()
#         df_pr = self.__preprocess_mulpiple_cat_features(df_pr)
        df_pr = self.__preprocess_skewed_num_features(df_pr)
        # df_pr = self.__preprocess_text_features(df_pr)
        
        return df_pr

# %%
preprocesser = Preprocesser(
#     mltpl_cat_features,
            skewed_num_features,
            #text_features,
#             mltpl_cat_n_top
                           )

# %%
df_pr = preprocesser.preprocess(prep_df)

# %%
df_pr.isnull().sum()
# Out:
# age_access_type       0
# name                  0
# type                  0
# release_year          0
# duration              0
#                      ..
# Сергей Сельянов       0
# Георгий Малков        0
# Тимур Бекмамбетов     0
# Роман Непомнящий      0
# Александр Боярский    0
# Length: 1053, dtype: int64

# %% [markdown]
# ### target destr

# %%
plt.figure(figsize=(10, 3))
sns.distplot(df_pr['target'])
plt.show()

plt.figure(figsize=(10, 3))
sns.boxplot(df_pr['target'].values, orient='h')
plt.show()

# %%
plt.figure(figsize=(10, 3))
sns.distplot(df_pr['target'].apply(lambda x: np.log1p(x)))
plt.show()

plt.figure(figsize=(10, 3))
x=df_pr['target'].apply(lambda x: np.log1p(x))
sns.boxplot(x.values, orient='h')
plt.show()

# %% [markdown]
# ## Split

# %%
df_pr.columns
# Out:
# Index(['age_access_type', 'name', 'type', 'release_year', 'duration',
#        'element_uid', 'BUDGET', 'MARKETING', 'RUS', 'USA',
#        ...
#        'Алексей Балабанов', 'Александр Амиров', 'Сергей Иванов',
#        'Сергей Трофимов', 'Максим Осадчий', 'Сергей Сельянов',
#        'Георгий Малков', 'Тимур Бекмамбетов', 'Роман Непомнящий',
#        'Александр Боярский'],
#       dtype='object', length=1053)

# %%
from sklearn.model_selection import train_test_split

sorted_df = df_pr.sort_values('release_year')

test = sorted_df[sorted_df['release_year'] == 2022]
train = sorted_df[sorted_df['release_year'] != 2022]

# for looking at samples
test_df = test.copy(deep=True)
train_df = train.copy(deep=True)

test.drop(['release_year', 'element_uid', 'name'], axis=1, inplace=True)
train.drop(['release_year', 'element_uid', 'name'], axis=1, inplace=True)


X_test, y_test = test.drop('target', axis=1), test['target']
y_test = y_test.apply(lambda x: np.log1p(x))

X, y = train.drop('target', axis=1), train['target']
y = y.apply(lambda x: np.log1p(x))
X_train, X_val, y_train, y_val = train_test_split(X, y,
                                                  test_size=0.1, 
                                                  shuffle=False)
X_train.shape, X_val.shape, X_test.shape, y_train.shape, y_val.shape, y_test.shape
# Out:
# ((363, 1049), (41, 1049), (7, 1049), (363,), (41,), (7,))

# %%
X_train.columns
# Out:
# Index(['age_access_type', 'type', 'duration', 'BUDGET', 'MARKETING', 'RUS',
#        'USA', 'WORLD', 'джек', 'расследовать',
#        ...
#        'Алексей Балабанов', 'Александр Амиров', 'Сергей Иванов',
#        'Сергей Трофимов', 'Максим Осадчий', 'Сергей Сельянов',
#        'Георгий Малков', 'Тимур Бекмамбетов', 'Роман Непомнящий',
#        'Александр Боярский'],
#       dtype='object', length=1049)

# %%
cat_features = ['age_access_type', 'type']

# %%
# sc
from sklearn.preprocessing import StandardScaler

sc_cols = ['duration', 'BUDGET', 'MARKETING', 'RUS', 'USA']

sc=StandardScaler()
sc_train = sc.fit_transform(X_train[sc_cols])

sc_train = pd.DataFrame(sc_train, index=X_train.index, columns=sc_cols)
X_train.drop(sc_cols, axis=1, inplace=True)
print(X_train.shape)
X_train = pd.concat([X_train, sc_train],axis=1)
print(X_train.shape)

# 
sc_val = sc.transform(X_val[sc_cols])
sc_val = pd.DataFrame(sc_val, index=X_val.index, columns=sc_cols)
X_val.drop(sc_cols, axis=1, inplace=True)
print(X_val.shape)
X_val = pd.concat([X_val, sc_val],axis=1) 
print(X_val.shape)

# 
sc_test = sc.transform(X_test[sc_cols])
sc_test = pd.DataFrame(sc_test, index=X_test.index, columns=sc_cols)
X_test.drop(sc_cols, axis=1, inplace=True)
print(X_test.shape)
X_test = pd.concat([X_test, sc_test],axis=1) 
print(X_test.shape)
# Out:
# (363, 1044)
# (363, 1049)
# (41, 1044)
# (41, 1049)
# (7, 1044)
# (7, 1049)

# %% [markdown]
# # Modeling

# %%
# !pip install catboost
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting catboost
#   Downloading catboost-1.1.1-cp39-none-manylinux1_x86_64.whl (76.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.6/76.6 MB 8.2 MB/s eta 0:00:00
# Requirement already satisfied: graphviz in /usr/local/lib/python3.9/dist-packages (from catboost) (0.20.1)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.9/dist-packages (from catboost) (1.22.4)
# Requirement already satisfied: pandas>=0.24.0 in /usr/local/lib/python3.9/dist-packages (from catboost) (1.4.4)
# Requirement already satisfied: plotly in /usr/local/lib/python3.9/dist-packages (from catboost) (5.13.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/dist-packages (from catboost) (1.10.1)
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from catboost) (1.16.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.9/dist-packages (from catboost) (3.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=0.24.0->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=0.24.0->catboost) (2022.7.1)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->catboost) (5.12.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->catboost) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->catboost) (1.4.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->catboost) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib->catboost) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->catboost) (4.39.3)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->catboost) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->catboost) (8.4.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from plotly->catboost) (8.2.2)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib-resources>=3.2.0->matplotlib->catboost) (3.15.0)
# Installing collected packages: catboost
# Successfully installed catboost-1.1.1

# %%
import catboost as cat
from catboost import CatBoostRegressor
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV

from scipy.stats import uniform, randint

# %%
train_dataset = cat.Pool(data=X_train,
                        label=y_train,
                         cat_features=cat_features)

test_dataset = cat.Pool(data=X_test, 
                        label=y_test,
                         cat_features=cat_features)

val_dataset = cat.Pool(X_val, y_val,
                       cat_features=cat_features)

cat_params = {
    'loss_function': 'RMSE',
    'eval_metric': 'MAE',
    'verbose': True,
    'random_seed': 321,
    'allow_writing_files': False, 
    'cat_features': cat_features
}

cat_model = cat.CatBoostRegressor(**cat_params)

cat_model.fit(
    train_dataset,
    eval_set=val_dataset,
    early_stopping_rounds=500,
    verbose=100,
    plot=False
)
# Out:
# Learning rate set to 0.043431
# 0:	learn: 0.0004689	test: 0.0075604	best: 0.0075604 (0)	total: 63.4ms	remaining: 1m 3s
# 100:	learn: 0.0003191	test: 0.0073526	best: 0.0073526 (100)	total: 1.37s	remaining: 12.2s
# 200:	learn: 0.0002379	test: 0.0072941	best: 0.0072941 (200)	total: 2.02s	remaining: 8.01s
# 300:	learn: 0.0001819	test: 0.0072815	best: 0.0072815 (299)	total: 3.08s	remaining: 7.16s
# 400:	learn: 0.0001469	test: 0.0072779	best: 0.0072775 (394)	total: 4.05s	remaining: 6.05s
# 500:	learn: 0.0001228	test: 0.0072777	best: 0.0072774 (494)	total: 4.88s	remaining: 4.86s
# 600:	learn: 0.0001052	test: 0.0072773	best: 0.0072765 (529)	total: 5.75s	remaining: 3.82s
# 700:	learn: 0.0000912	test: 0.0072786	best: 0.0072765 (529)	total: 6.13s	remaining: 2.62s
# 800:	learn: 0.0000806	test: 0.0072794	best: 0.0072765 (529)	total: 6.51s	remaining: 1.62s
# 900:	learn: 0.0000713	test: 0.0072809	best: 0.0072765 (529)	total: 7.19s	remaining: 790ms
# 999:	learn: 0.0000632	test: 0.0072819	best: 0.0072765 (529)	total: 7.95s	remaining: 0us
#
# bestTest = 0.007276515476
# bestIteration = 529
#
# Shrink model to first 530 iterations.

# %%
y_pred = cat_model.predict(test_dataset)

# %%
target_distr_linear(y_train, y_test, y_pred)

# %%
def inverse_transform(feature):
    return np.expm1(feature)

calc_metrics(inverse_transform(y_test), inverse_transform(y_pred))
# Out:
# *** VAL **:
# MSE:   0.00018234895023751287
# RMSE:  0.013503664326304652
# R2:    -2.4867152434781814
# MAE:   0.0113932911298217
# MedAE: 0.012033855572419516
# ------------------------------

# %%
# errors = y_test - y_pred
# draw_res_analys(errors, y_pred)

# %% [markdown]
# **Conclusion**
# * The trend in the second figure is not visible, now we will confirm the presence of heteroskedasticity on tests.

# %%
def get_feature_imp(model, X_train):
    imp = model.get_feature_importance(data=X_train)
    imp_features_df = pd.DataFrame({"score":imp, "feat": model.feature_names_})
    imp_features_df = imp_features_df.sort_values(by='score')[-20:]

    fig, axes = plt.subplots(1, 1, figsize=(12, 8))
    axes.barh(width=imp_features_df['score'].values, y=imp_features_df["feat"].values)
    axes.set_title('Finetuned Catboost feature importance')
    plt.show()

# %%
get_feature_imp(cat_model, train_dataset)

# %%
test_df['PREDS'] = y_pred.tolist()
test_df['TARGET'] = y_test.tolist()
test_df
# Out:
#     age_access_type                    name   type  release_year   duration  \
# 710              18                    Ника  MOVIE          2022  15.566448
# 396              18               Приплыли!  MOVIE          2022  15.479437
# 158              16             Многоэтажка  MOVIE          2022  15.597220
# 747              12           Тайна амулета  MOVIE          2022  15.545395
# 203              16  День слепого Валентина  MOVIE          2022  15.711630
# 332              16          Доктор Свисток  MOVIE          2022  15.332833
# 711              12            Первый Оскар  MOVIE          2022  15.738298
#
#                               element_uid  BUDGET  MARKETING        RUS  USA  \
# 710  5bd9b8c0-b482-4953-951a-813985e55e2d     NaN        NaN  12.233522  NaN
# 396  02eaefe0-296d-4e6f-b52f-2e2507d07103     NaN        NaN  12.593543  NaN
# 158  19a61cc3-65ff-46ce-bf43-29c24a1cc9b6     NaN        NaN   5.793014  NaN
# 747  9ae35927-93e3-4a40-870f-a998abbeaa9f     NaN        NaN  12.057422  NaN
# 203  6b047b99-5cb4-4878-9a4f-b8b372b438eb     NaN        NaN  12.935033  NaN
# 332  967bf940-27b7-4d93-95ad-43c7459077e7     NaN        NaN  12.638501  NaN
# 711  e69d2f4d-bb65-4e7e-93e1-74da99424ae8     NaN        NaN  14.252288  NaN
#
#      ...  Сергей Иванов  Сергей Трофимов  Максим Осадчий  Сергей Сельянов  \
# 710  ...              0                0               0                0
# 396  ...              0                0               0                0
# 158  ...              0                0               0                0
# 747  ...              0                0               0                0
# 203  ...              0                0               0                0
# 332  ...              0                0               0                0
# 711  ...              0                0               0                0
#
#      Георгий Малков  Тимур Бекмамбетов  Роман Непомнящий  Александр Боярский  \
# 710               0                  0                 0                   0
# 396               0                  0                 0                   0
# 158               0                  0                 0                   0
# 747               0                  0                 0                   0
# 203               0                  0                 0                   0
# 332               1                  0                 0                   0
# 711               0                  0                 0                   0
#
#         PREDS    TARGET
# 710  0.000095  0.004464
# 396  0.000698  0.009902
# 158  0.000127  0.017114
# 747  0.000139  0.000178
# 203  0.000083  0.023361
# 332  0.000070  0.012031
# 711  0.000470  0.013736
#
# [7 rows x 1055 columns]

# %%
# predict demo dataset

# %% [markdown]
# # Tuning

# %%
train_dataset = cat.Pool(X_train, y_train, 
                         cat_features=cat_features) 

test_dataset = cat.Pool(X_test, y_test,
                         cat_features=cat_features)

cat_params = {
    'loss_function': 'RMSE',
    'eval_metric': 'MAE',
    'verbose': True,
    'random_seed': 321,
    'allow_writing_files': False, 
    'cat_features': cat_features
}

# %%
parameters_distr = {'depth': randint(5, 10),
              'learning_rate': uniform(0.01, 0.1),
              'iterations': [5000, 10000, 15000]
             }

cat_model = cat.CatBoostRegressor(**cat_params)
grid = RandomizedSearchCV(estimator=cat_model, param_distributions=parameters_distr, 
                            cv=5, 
                          n_jobs=-1,
                          verbose=3)

grid.fit(X_train, y_train)

import pickle
with open('bestimator_okko_rat_ntop_scrs_kws_views_russ', 'wb') as f:
    pickle.dump(grid.best_estimator_, f)
grid.best_params_
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
# 0:	learn: 0.0004692	total: 20.6ms	remaining: 1m 43s
# 1:	learn: 0.0004675	total: 23ms	remaining: 57.4s
# 2:	learn: 0.0004639	total: 40.7ms	remaining: 1m 7s
# 3:	learn: 0.0004619	total: 57.1ms	remaining: 1m 11s
# 4:	learn: 0.0004591	total: 74.1ms	remaining: 1m 13s
# 5:	learn: 0.0004564	total: 90.6ms	remaining: 1m 15s
# 6:	learn: 0.0004541	total: 107ms	remaining: 1m 16s
# 7:	learn: 0.0004526	total: 124ms	remaining: 1m 17s
# 8:	learn: 0.0004489	total: 141ms	remaining: 1m 18s
# 9:	learn: 0.0004466	total: 157ms	remaining: 1m 18s
# 10:	learn: 0.0004442	total: 174ms	remaining: 1m 18s
# 11:	learn: 0.0004413	total: 190ms	remaining: 1m 18s
# 12:	learn: 0.0004399	total: 206ms	remaining: 1m 19s
# 13:	learn: 0.0004377	total: 229ms	remaining: 1m 21s
# 14:	learn: 0.0004343	total: 247ms	remaining: 1m 22s
# 15:	learn: 0.0004313	total: 264ms	remaining: 1m 22s
# 16:	learn: 0.0004293	total: 281ms	remaining: 1m 22s
# 17:	learn: 0.0004276	total: 298ms	remaining: 1m 22s
# 18:	learn: 0.0004259	total: 314ms	remaining: 1m 22s
# 19:	learn: 0.0004235	total: 332ms	remaining: 1m 22s
# 20:	learn: 0.0004220	total: 349ms	remaining: 1m 22s
# 21:	learn: 0.0004201	total: 365ms	remaining: 1m 22s
# 22:	learn: 0.0004174	total: 383ms	remaining: 1m 22s
# 23:	learn: 0.0004156	total: 399ms	remaining: 1m 22s
# 24:	learn: 0.0004137	total: 417ms	remaining: 1m 22s
# 25:	learn: 0.0004115	total: 437ms	remaining: 1m 23s
# 26:	learn: 0.0004102	total: 456ms	remaining: 1m 24s
# 27:	learn: 0.0004082	total: 473ms	remaining: 1m 24s
# 28:	learn: 0.0004056	total: 491ms	remaining: 1m 24s
# 29:	learn: 0.0004037	total: 507ms	remaining: 1m 24s
# 30:	learn: 0.0004018	total: 524ms	remaining: 1m 24s
# 31:	learn: 0.0003993	total: 541ms	remaining: 1m 24s
# 32:	learn: 0.0003973	total: 559ms	remaining: 1m 24s
# 33:	learn: 0.0003963	total: 576ms	remaining: 1m 24s
# 34:	learn: 0.0003951	total: 592ms	remaining: 1m 24s
# 35:	learn: 0.0003932	total: 609ms	remaining: 1m 23s
# 36:	learn: 0.0003906	total: 619ms	remaining: 1m 23s
# 37:	learn: 0.0003897	total: 639ms	remaining: 1m 23s
# 38:	learn: 0.0003883	total: 661ms	remaining: 1m 24s
# 39:	learn: 0.0003868	total: 677ms	remaining: 1m 23s
# 40:	learn: 0.0003853	total: 694ms	remaining: 1m 23s
# 41:	learn: 0.0003837	total: 700ms	remaining: 1m 22s
# 42:	learn: 0.0003819	total: 716ms	remaining: 1m 22s
# 43:	learn: 0.0003798	total: 733ms	remaining: 1m 22s
# 44:	learn: 0.0003785	total: 749ms	remaining: 1m 22s
# 45:	learn: 0.0003771	total: 766ms	remaining: 1m 22s
# 46:	learn: 0.0003744	total: 782ms	remaining: 1m 22s
# 47:	learn: 0.0003738	total: 813ms	remaining: 1m 23s
# 48:	learn: 0.0003719	total: 829ms	remaining: 1m 23s
# 49:	learn: 0.0003709	total: 849ms	remaining: 1m 24s
# 50:	learn: 0.0003705	total: 866ms	remaining: 1m 24s
# 51:	learn: 0.0003685	total: 883ms	remaining: 1m 23s
# 52:	learn: 0.0003665	total: 898ms	remaining: 1m 23s
# 53:	learn: 0.0003645	total: 915ms	remaining: 1m 23s
# 54:	learn: 0.0003626	total: 931ms	remaining: 1m 23s
# 55:	learn: 0.0003615	total: 947ms	remaining: 1m 23s
# 56:	learn: 0.0003606	total: 963ms	remaining: 1m 23s
# 57:	learn: 0.0003583	total: 979ms	remaining: 1m 23s
# 58:	learn: 0.0003573	total: 989ms	remaining: 1m 22s
# 59:	learn: 0.0003557	total: 1s	remaining: 1m 22s
# 60:	learn: 0.0003548	total: 1.02s	remaining: 1m 22s
# 61:	learn: 0.0003536	total: 1.04s	remaining: 1m 22s
# 62:	learn: 0.0003515	total: 1.06s	remaining: 1m 22s
# 63:	learn: 0.0003504	total: 1.07s	remaining: 1m 22s
# 64:	learn: 0.0003491	total: 1.09s	remaining: 1m 22s
# 65:	learn: 0.0003478	total: 1.11s	remaining: 1m 22s
# 66:	learn: 0.0003475	total: 1.12s	remaining: 1m 22s
# 67:	learn: 0.0003466	total: 1.14s	remaining: 1m 22s
# 68:	learn: 0.0003453	total: 1.16s	remaining: 1m 22s
# 69:	learn: 0.0003440	total: 1.18s	remaining: 1m 22s
# 70:	learn: 0.0003434	total: 1.19s	remaining: 1m 22s
# 71:	learn: 0.0003421	total: 1.21s	remaining: 1m 22s
# 72:	learn: 0.0003412	total: 1.22s	remaining: 1m 22s
# 73:	learn: 0.0003405	total: 1.24s	remaining: 1m 22s
# 74:	learn: 0.0003391	total: 1.26s	remaining: 1m 23s
# 75:	learn: 0.0003383	total: 1.27s	remaining: 1m 22s
# 76:	learn: 0.0003371	total: 1.29s	remaining: 1m 22s
# 77:	learn: 0.0003356	total: 1.31s	remaining: 1m 22s
# 78:	learn: 0.0003341	total: 1.32s	remaining: 1m 22s
# 79:	learn: 0.0003328	total: 1.34s	remaining: 1m 22s
# 80:	learn: 0.0003324	total: 1.36s	remaining: 1m 22s
# 81:	learn: 0.0003317	total: 1.38s	remaining: 1m 22s
# 82:	learn: 0.0003303	total: 1.4s	remaining: 1m 22s
# 83:	learn: 0.0003289	total: 1.42s	remaining: 1m 22s
# 84:	learn: 0.0003279	total: 1.43s	remaining: 1m 22s
# 85:	learn: 0.0003270	total: 1.45s	remaining: 1m 22s
# 86:	learn: 0.0003257	total: 1.48s	remaining: 1m 23s
# 87:	learn: 0.0003237	total: 1.5s	remaining: 1m 23s
# 88:	learn: 0.0003227	total: 1.51s	remaining: 1m 23s
# 89:	learn: 0.0003217	total: 1.53s	remaining: 1m 23s
# 90:	learn: 0.0003208	total: 1.55s	remaining: 1m 23s
# 91:	learn: 0.0003198	total: 1.57s	remaining: 1m 23s
# 92:	learn: 0.0003186	total: 1.58s	remaining: 1m 23s
# 93:	learn: 0.0003180	total: 1.59s	remaining: 1m 23s
# 94:	learn: 0.0003170	total: 1.61s	remaining: 1m 23s
# 95:	learn: 0.0003158	total: 1.64s	remaining: 1m 23s
# 96:	learn: 0.0003153	total: 1.64s	remaining: 1m 22s
# 97:	learn: 0.0003145	total: 1.66s	remaining: 1m 22s
# 98:	learn: 0.0003127	total: 1.68s	remaining: 1m 23s
# 99:	learn: 0.0003113	total: 1.7s	remaining: 1m 23s
# 100:	learn: 0.0003105	total: 1.7s	remaining: 1m 22s
# 101:	learn: 0.0003094	total: 1.72s	remaining: 1m 22s
# 102:	learn: 0.0003085	total: 1.74s	remaining: 1m 22s
# 103:	learn: 0.0003079	total: 1.74s	remaining: 1m 21s
# 104:	learn: 0.0003066	total: 1.76s	remaining: 1m 22s
# 105:	learn: 0.0003055	total: 1.78s	remaining: 1m 22s
# 106:	learn: 0.0003045	total: 1.8s	remaining: 1m 22s
# 107:	learn: 0.0003034	total: 1.83s	remaining: 1m 22s
# 108:	learn: 0.0003023	total: 1.85s	remaining: 1m 22s
# 109:	learn: 0.0003014	total: 1.87s	remaining: 1m 23s
# 110:	learn: 0.0003005	total: 1.89s	remaining: 1m 23s
# 111:	learn: 0.0002990	total: 1.91s	remaining: 1m 23s
# 112:	learn: 0.0002983	total: 1.92s	remaining: 1m 23s
# 113:	learn: 0.0002971	total: 1.94s	remaining: 1m 23s
# 114:	learn: 0.0002968	total: 1.96s	remaining: 1m 23s
# 115:	learn: 0.0002961	total: 1.98s	remaining: 1m 23s
# 116:	learn: 0.0002949	total: 1.99s	remaining: 1m 23s
# 117:	learn: 0.0002939	total: 2.01s	remaining: 1m 23s
# 118:	learn: 0.0002935	total: 2.03s	remaining: 1m 23s
# 119:	learn: 0.0002926	total: 2.05s	remaining: 1m 23s
# 120:	learn: 0.0002916	total: 2.06s	remaining: 1m 23s
# 121:	learn: 0.0002908	total: 2.08s	remaining: 1m 23s
# 122:	learn: 0.0002899	total: 2.1s	remaining: 1m 23s
# 123:	learn: 0.0002893	total: 2.12s	remaining: 1m 23s
# 124:	learn: 0.0002884	total: 2.14s	remaining: 1m 23s
# 125:	learn: 0.0002875	total: 2.15s	remaining: 1m 23s
# 126:	learn: 0.0002864	total: 2.17s	remaining: 1m 23s
# 127:	learn: 0.0002857	total: 2.19s	remaining: 1m 23s
# 128:	learn: 0.0002847	total: 2.21s	remaining: 1m 23s
# 129:	learn: 0.0002837	total: 2.23s	remaining: 1m 23s
# 130:	learn: 0.0002825	total: 2.25s	remaining: 1m 23s
# 131:	learn: 0.0002817	total: 2.27s	remaining: 1m 23s
# 132:	learn: 0.0002806	total: 2.28s	remaining: 1m 23s
# 133:	learn: 0.0002798	total: 2.3s	remaining: 1m 23s
# 134:	learn: 0.0002791	total: 2.31s	remaining: 1m 23s
# 135:	learn: 0.0002784	total: 2.32s	remaining: 1m 22s
# 136:	learn: 0.0002779	total: 2.34s	remaining: 1m 23s
# 137:	learn: 0.0002769	total: 2.36s	remaining: 1m 23s
# 138:	learn: 0.0002755	total: 2.41s	remaining: 1m 24s
# 139:	learn: 0.0002745	total: 2.44s	remaining: 1m 24s
# 140:	learn: 0.0002736	total: 2.47s	remaining: 1m 25s
# 141:	learn: 0.0002727	total: 2.51s	remaining: 1m 25s
# 142:	learn: 0.0002721	total: 2.55s	remaining: 1m 26s
# 143:	learn: 0.0002711	total: 2.58s	remaining: 1m 27s
# 144:	learn: 0.0002699	total: 2.62s	remaining: 1m 27s
# 145:	learn: 0.0002692	total: 2.66s	remaining: 1m 28s
# 146:	learn: 0.0002680	total: 2.69s	remaining: 1m 28s
# 147:	learn: 0.0002671	total: 2.72s	remaining: 1m 29s
# 148:	learn: 0.0002660	total: 2.74s	remaining: 1m 29s
# 149:	learn: 0.0002650	total: 2.77s	remaining: 1m 29s
# 150:	learn: 0.0002642	total: 2.81s	remaining: 1m 30s
# 151:	learn: 0.0002632	total: 2.85s	remaining: 1m 30s
# 152:	learn: 0.0002623	total: 2.88s	remaining: 1m 31s
# 153:	learn: 0.0002614	total: 2.92s	remaining: 1m 31s
# 154:	learn: 0.0002605	total: 2.96s	remaining: 1m 32s
# 155:	learn: 0.0002598	total: 3s	remaining: 1m 33s
# 156:	learn: 0.0002587	total: 3.02s	remaining: 1m 33s
# 157:	learn: 0.0002576	total: 3.06s	remaining: 1m 33s
# 158:	learn: 0.0002565	total: 3.1s	remaining: 1m 34s
# 159:	learn: 0.0002559	total: 3.13s	remaining: 1m 34s
# 160:	learn: 0.0002550	total: 3.17s	remaining: 1m 35s
# 161:	learn: 0.0002544	total: 3.2s	remaining: 1m 35s
# 162:	learn: 0.0002536	total: 3.23s	remaining: 1m 35s
# 163:	learn: 0.0002526	total: 3.26s	remaining: 1m 36s
# 164:	learn: 0.0002518	total: 3.29s	remaining: 1m 36s
# 165:	learn: 0.0002508	total: 3.32s	remaining: 1m 36s
# 166:	learn: 0.0002498	total: 3.36s	remaining: 1m 37s
# 167:	learn: 0.0002493	total: 3.39s	remaining: 1m 37s
# 168:	learn: 0.0002486	total: 3.42s	remaining: 1m 37s
# 169:	learn: 0.0002477	total: 3.46s	remaining: 1m 38s
# 170:	learn: 0.0002466	total: 3.5s	remaining: 1m 38s
# 171:	learn: 0.0002457	total: 3.54s	remaining: 1m 39s
# 172:	learn: 0.0002451	total: 3.58s	remaining: 1m 39s
# 173:	learn: 0.0002441	total: 3.62s	remaining: 1m 40s
# 174:	learn: 0.0002433	total: 3.66s	remaining: 1m 40s
# 175:	learn: 0.0002425	total: 3.69s	remaining: 1m 41s
# 176:	learn: 0.0002419	total: 3.73s	remaining: 1m 41s
# 177:	learn: 0.0002408	total: 3.76s	remaining: 1m 41s
# 178:	learn: 0.0002400	total: 3.8s	remaining: 1m 42s
# 179:	learn: 0.0002391	total: 3.84s	remaining: 1m 42s
# 180:	learn: 0.0002379	total: 3.88s	remaining: 1m 43s
# 181:	learn: 0.0002371	total: 3.91s	remaining: 1m 43s
# 182:	learn: 0.0002362	total: 3.95s	remaining: 1m 44s
# 183:	learn: 0.0002353	total: 3.99s	remaining: 1m 44s
# 184:	learn: 0.0002344	total: 4.03s	remaining: 1m 44s
# 185:	learn: 0.0002336	total: 4.07s	remaining: 1m 45s
# 186:	learn: 0.0002326	total: 4.1s	remaining: 1m 45s
# 187:	learn: 0.0002317	total: 4.14s	remaining: 1m 45s
# 188:	learn: 0.0002310	total: 4.18s	remaining: 1m 46s
# 189:	learn: 0.0002301	total: 4.22s	remaining: 1m 46s
# 190:	learn: 0.0002292	total: 4.26s	remaining: 1m 47s
# 191:	learn: 0.0002284	total: 4.31s	remaining: 1m 47s
# 192:	learn: 0.0002275	total: 4.35s	remaining: 1m 48s
# 193:	learn: 0.0002267	total: 4.39s	remaining: 1m 48s
# 194:	learn: 0.0002261	total: 4.42s	remaining: 1m 49s
# 195:	learn: 0.0002253	total: 4.46s	remaining: 1m 49s
# 196:	learn: 0.0002246	total: 4.5s	remaining: 1m 49s
# 197:	learn: 0.0002234	total: 4.54s	remaining: 1m 50s
# 198:	learn: 0.0002226	total: 4.57s	remaining: 1m 50s
# 199:	learn: 0.0002219	total: 4.59s	remaining: 1m 50s
# 200:	learn: 0.0002212	total: 4.62s	remaining: 1m 50s
# 201:	learn: 0.0002205	total: 4.65s	remaining: 1m 50s
# 202:	learn: 0.0002198	total: 4.68s	remaining: 1m 50s
# 203:	learn: 0.0002188	total: 4.71s	remaining: 1m 50s
# 204:	learn: 0.0002182	total: 4.74s	remaining: 1m 50s
# 205:	learn: 0.0002176	total: 4.77s	remaining: 1m 51s
# 206:	learn: 0.0002170	total: 4.81s	remaining: 1m 51s
# 207:	learn: 0.0002163	total: 4.85s	remaining: 1m 51s
# 208:	learn: 0.0002158	total: 4.88s	remaining: 1m 51s
# 209:	learn: 0.0002152	total: 4.92s	remaining: 1m 52s
# 210:	learn: 0.0002144	total: 4.97s	remaining: 1m 52s
# 211:	learn: 0.0002137	total: 5s	remaining: 1m 52s
# 212:	learn: 0.0002125	total: 5.03s	remaining: 1m 52s
# 213:	learn: 0.0002119	total: 5.06s	remaining: 1m 53s
# 214:	learn: 0.0002109	total: 5.09s	remaining: 1m 53s
# 215:	learn: 0.0002103	total: 5.13s	remaining: 1m 53s
# 216:	learn: 0.0002098	total: 5.16s	remaining: 1m 53s
# 217:	learn: 0.0002086	total: 5.2s	remaining: 1m 54s
# 218:	learn: 0.0002080	total: 5.24s	remaining: 1m 54s
# 219:	learn: 0.0002068	total: 5.27s	remaining: 1m 54s
# 220:	learn: 0.0002063	total: 5.31s	remaining: 1m 54s
# 221:	learn: 0.0002053	total: 5.35s	remaining: 1m 55s
# 222:	learn: 0.0002045	total: 5.39s	remaining: 1m 55s
# 223:	learn: 0.0002040	total: 5.43s	remaining: 1m 55s
# 224:	learn: 0.0002028	total: 5.47s	remaining: 1m 56s
# 225:	learn: 0.0002025	total: 5.5s	remaining: 1m 56s
# 226:	learn: 0.0002020	total: 5.54s	remaining: 1m 56s
# 227:	learn: 0.0002009	total: 5.58s	remaining: 1m 56s
# 228:	learn: 0.0002003	total: 5.62s	remaining: 1m 57s
# 229:	learn: 0.0001998	total: 5.66s	remaining: 1m 57s
# 230:	learn: 0.0001993	total: 5.69s	remaining: 1m 57s
# 231:	learn: 0.0001988	total: 5.72s	remaining: 1m 57s
# 232:	learn: 0.0001983	total: 5.75s	remaining: 1m 57s
# 233:	learn: 0.0001978	total: 5.78s	remaining: 1m 57s
# 234:	learn: 0.0001973	total: 5.81s	remaining: 1m 57s
# 235:	learn: 0.0001962	total: 5.85s	remaining: 1m 58s
# 236:	learn: 0.0001955	total: 5.9s	remaining: 1m 58s
# 237:	learn: 0.0001950	total: 5.93s	remaining: 1m 58s
# 238:	learn: 0.0001936	total: 5.98s	remaining: 1m 59s
# 239:	learn: 0.0001931	total: 6.01s	remaining: 1m 59s
# 240:	learn: 0.0001920	total: 6.05s	remaining: 1m 59s
# 241:	learn: 0.0001915	total: 6.08s	remaining: 1m 59s
# 242:	learn: 0.0001907	total: 6.11s	remaining: 1m 59s
# 243:	learn: 0.0001903	total: 6.13s	remaining: 1m 59s
# 244:	learn: 0.0001892	total: 6.16s	remaining: 1m 59s
# 245:	learn: 0.0001883	total: 6.2s	remaining: 1m 59s
# 246:	learn: 0.0001879	total: 6.22s	remaining: 1m 59s
# 247:	learn: 0.0001865	total: 6.26s	remaining: 2m
# 248:	learn: 0.0001861	total: 6.31s	remaining: 2m
# 249:	learn: 0.0001858	total: 6.35s	remaining: 2m
# 250:	learn: 0.0001853	total: 6.39s	remaining: 2m
# 251:	learn: 0.0001846	total: 6.42s	remaining: 2m 1s
# 252:	learn: 0.0001842	total: 6.46s	remaining: 2m 1s
# 253:	learn: 0.0001835	total: 6.5s	remaining: 2m 1s
# 254:	learn: 0.0001831	total: 6.54s	remaining: 2m 1s
# 255:	learn: 0.0001827	total: 6.58s	remaining: 2m 1s
# 256:	learn: 0.0001817	total: 6.63s	remaining: 2m 2s
# 257:	learn: 0.0001814	total: 6.66s	remaining: 2m 2s
# 258:	learn: 0.0001804	total: 6.69s	remaining: 2m 2s
# 259:	learn: 0.0001795	total: 6.74s	remaining: 2m 2s
# 260:	learn: 0.0001785	total: 6.78s	remaining: 2m 3s
# 261:	learn: 0.0001781	total: 6.82s	remaining: 2m 3s
# 262:	learn: 0.0001772	total: 6.86s	remaining: 2m 3s
# 263:	learn: 0.0001765	total: 6.89s	remaining: 2m 3s
# 264:	learn: 0.0001758	total: 6.93s	remaining: 2m 3s
# 265:	learn: 0.0001753	total: 6.97s	remaining: 2m 4s
# 266:	learn: 0.0001749	total: 6.99s	remaining: 2m 3s
# 267:	learn: 0.0001742	total: 7s	remaining: 2m 3s
# 268:	learn: 0.0001733	total: 7.02s	remaining: 2m 3s
# 269:	learn: 0.0001725	total: 7.04s	remaining: 2m 3s
# 270:	learn: 0.0001722	total: 7.05s	remaining: 2m 3s
# 271:	learn: 0.0001713	total: 7.07s	remaining: 2m 2s
# 272:	learn: 0.0001704	total: 7.09s	remaining: 2m 2s
# 273:	learn: 0.0001699	total: 7.11s	remaining: 2m 2s
# 274:	learn: 0.0001696	total: 7.12s	remaining: 2m 2s
# 275:	learn: 0.0001688	total: 7.14s	remaining: 2m 2s
# 276:	learn: 0.0001680	total: 7.16s	remaining: 2m 2s
# 277:	learn: 0.0001677	total: 7.18s	remaining: 2m 1s
# 278:	learn: 0.0001670	total: 7.19s	remaining: 2m 1s
# 279:	learn: 0.0001663	total: 7.21s	remaining: 2m 1s
# 280:	learn: 0.0001655	total: 7.23s	remaining: 2m 1s
# 281:	learn: 0.0001647	total: 7.25s	remaining: 2m 1s
# 282:	learn: 0.0001641	total: 7.26s	remaining: 2m 1s
# 283:	learn: 0.0001636	total: 7.28s	remaining: 2m
# 284:	learn: 0.0001629	total: 7.3s	remaining: 2m
# 285:	learn: 0.0001620	total: 7.31s	remaining: 2m
# 286:	learn: 0.0001617	total: 7.33s	remaining: 2m
# 287:	learn: 0.0001614	total: 7.35s	remaining: 2m
# 288:	learn: 0.0001611	total: 7.36s	remaining: 2m
# 289:	learn: 0.0001609	total: 7.38s	remaining: 1m 59s
# 290:	learn: 0.0001606	total: 7.4s	remaining: 1m 59s
# 291:	learn: 0.0001598	total: 7.42s	remaining: 1m 59s
# 292:	learn: 0.0001592	total: 7.44s	remaining: 1m 59s
# 293:	learn: 0.0001586	total: 7.45s	remaining: 1m 59s
# 294:	learn: 0.0001583	total: 7.47s	remaining: 1m 59s
# 295:	learn: 0.0001580	total: 7.49s	remaining: 1m 58s
# 296:	learn: 0.0001570	total: 7.5s	remaining: 1m 58s
# 297:	learn: 0.0001567	total: 7.52s	remaining: 1m 58s
# 298:	learn: 0.0001564	total: 7.54s	remaining: 1m 58s
# 299:	learn: 0.0001559	total: 7.56s	remaining: 1m 58s
# 300:	learn: 0.0001552	total: 7.57s	remaining: 1m 58s
# 301:	learn: 0.0001549	total: 7.59s	remaining: 1m 58s
# 302:	learn: 0.0001543	total: 7.62s	remaining: 1m 58s
# 303:	learn: 0.0001537	total: 7.64s	remaining: 1m 57s
# 304:	learn: 0.0001532	total: 7.65s	remaining: 1m 57s
# 305:	learn: 0.0001530	total: 7.67s	remaining: 1m 57s
# 306:	learn: 0.0001521	total: 7.69s	remaining: 1m 57s
# 307:	learn: 0.0001516	total: 7.7s	remaining: 1m 57s
# 308:	learn: 0.0001508	total: 7.72s	remaining: 1m 57s
# 309:	learn: 0.0001504	total: 7.74s	remaining: 1m 57s
# 310:	learn: 0.0001501	total: 7.76s	remaining: 1m 57s
# 311:	learn: 0.0001493	total: 7.78s	remaining: 1m 56s
# 312:	learn: 0.0001483	total: 7.8s	remaining: 1m 56s
# 313:	learn: 0.0001481	total: 7.82s	remaining: 1m 56s
# 314:	learn: 0.0001474	total: 7.83s	remaining: 1m 56s
# 315:	learn: 0.0001469	total: 7.85s	remaining: 1m 56s
# 316:	learn: 0.0001465	total: 7.87s	remaining: 1m 56s
# 317:	learn: 0.0001462	total: 7.88s	remaining: 1m 56s
# 318:	learn: 0.0001460	total: 7.9s	remaining: 1m 55s
# 319:	learn: 0.0001457	total: 7.92s	remaining: 1m 55s
# 320:	learn: 0.0001454	total: 7.93s	remaining: 1m 55s
# 321:	learn: 0.0001450	total: 7.96s	remaining: 1m 55s
# 322:	learn: 0.0001447	total: 7.98s	remaining: 1m 55s
# 323:	learn: 0.0001445	total: 8s	remaining: 1m 55s
# 324:	learn: 0.0001435	total: 8.02s	remaining: 1m 55s
# 325:	learn: 0.0001431	total: 8.04s	remaining: 1m 55s
# 326:	learn: 0.0001429	total: 8.05s	remaining: 1m 55s
# 327:	learn: 0.0001419	total: 8.07s	remaining: 1m 55s
# 328:	learn: 0.0001416	total: 8.09s	remaining: 1m 54s
# 329:	learn: 0.0001411	total: 8.11s	remaining: 1m 54s
# 330:	learn: 0.0001408	total: 8.13s	remaining: 1m 54s
# 331:	learn: 0.0001403	total: 8.14s	remaining: 1m 54s
# 332:	learn: 0.0001397	total: 8.16s	remaining: 1m 54s
# 333:	learn: 0.0001388	total: 8.18s	remaining: 1m 54s
# 334:	learn: 0.0001385	total: 8.2s	remaining: 1m 54s
# 335:	learn: 0.0001382	total: 8.22s	remaining: 1m 54s
# 336:	learn: 0.0001376	total: 8.24s	remaining: 1m 54s
# 337:	learn: 0.0001367	total: 8.26s	remaining: 1m 53s
# 338:	learn: 0.0001365	total: 8.27s	remaining: 1m 53s
# 339:	learn: 0.0001360	total: 8.29s	remaining: 1m 53s
# 340:	learn: 0.0001358	total: 8.31s	remaining: 1m 53s
# 341:	learn: 0.0001354	total: 8.33s	remaining: 1m 53s
# 342:	learn: 0.0001344	total: 8.35s	remaining: 1m 53s
# 343:	learn: 0.0001343	total: 8.36s	remaining: 1m 53s
# 344:	learn: 0.0001334	total: 8.38s	remaining: 1m 53s
# 345:	learn: 0.0001330	total: 8.4s	remaining: 1m 52s
# 346:	learn: 0.0001328	total: 8.42s	remaining: 1m 52s
# 347:	learn: 0.0001325	total: 8.44s	remaining: 1m 52s
# 348:	learn: 0.0001323	total: 8.46s	remaining: 1m 52s
# 349:	learn: 0.0001318	total: 8.48s	remaining: 1m 52s
# 350:	learn: 0.0001313	total: 8.5s	remaining: 1m 52s
# 351:	learn: 0.0001311	total: 8.52s	remaining: 1m 52s
# 352:	learn: 0.0001308	total: 8.53s	remaining: 1m 52s
# 353:	learn: 0.0001303	total: 8.56s	remaining: 1m 52s
# 354:	learn: 0.0001301	total: 8.58s	remaining: 1m 52s
# 355:	learn: 0.0001293	total: 8.6s	remaining: 1m 52s
# 356:	learn: 0.0001290	total: 8.62s	remaining: 1m 52s
# 357:	learn: 0.0001287	total: 8.64s	remaining: 1m 51s
# 358:	learn: 0.0001278	total: 8.65s	remaining: 1m 51s
# 359:	learn: 0.0001272	total: 8.67s	remaining: 1m 51s
# 360:	learn: 0.0001269	total: 8.69s	remaining: 1m 51s
# 361:	learn: 0.0001267	total: 8.71s	remaining: 1m 51s
# 362:	learn: 0.0001265	total: 8.72s	remaining: 1m 51s
# 363:	learn: 0.0001262	total: 8.74s	remaining: 1m 51s
# 364:	learn: 0.0001260	total: 8.76s	remaining: 1m 51s
# 365:	learn: 0.0001254	total: 8.78s	remaining: 1m 51s
# 366:	learn: 0.0001252	total: 8.79s	remaining: 1m 51s
# 367:	learn: 0.0001246	total: 8.81s	remaining: 1m 50s
# 368:	learn: 0.0001239	total: 8.83s	remaining: 1m 50s
# 369:	learn: 0.0001236	total: 8.85s	remaining: 1m 50s
# 370:	learn: 0.0001234	total: 8.87s	remaining: 1m 50s
# 371:	learn: 0.0001226	total: 8.88s	remaining: 1m 50s
# 372:	learn: 0.0001218	total: 8.9s	remaining: 1m 50s
# 373:	learn: 0.0001215	total: 8.92s	remaining: 1m 50s
# 374:	learn: 0.0001214	total: 8.94s	remaining: 1m 50s
# 375:	learn: 0.0001207	total: 8.95s	remaining: 1m 50s
# 376:	learn: 0.0001204	total: 8.98s	remaining: 1m 50s
# 377:	learn: 0.0001203	total: 9s	remaining: 1m 50s
# 378:	learn: 0.0001197	total: 9.02s	remaining: 1m 49s
# 379:	learn: 0.0001192	total: 9.04s	remaining: 1m 49s
# 380:	learn: 0.0001189	total: 9.06s	remaining: 1m 49s
# 381:	learn: 0.0001187	total: 9.07s	remaining: 1m 49s
# 382:	learn: 0.0001184	total: 9.09s	remaining: 1m 49s
# 383:	learn: 0.0001182	total: 9.11s	remaining: 1m 49s
# 384:	learn: 0.0001180	total: 9.13s	remaining: 1m 49s
# 385:	learn: 0.0001173	total: 9.14s	remaining: 1m 49s
# 386:	learn: 0.0001171	total: 9.16s	remaining: 1m 49s
# 387:	learn: 0.0001167	total: 9.18s	remaining: 1m 49s
# 388:	learn: 0.0001162	total: 9.2s	remaining: 1m 49s
# 389:	learn: 0.0001160	total: 9.21s	remaining: 1m 48s
# 390:	learn: 0.0001158	total: 9.23s	remaining: 1m 48s
# 391:	learn: 0.0001155	total: 9.25s	remaining: 1m 48s
# 392:	learn: 0.0001149	total: 9.27s	remaining: 1m 48s
# 393:	learn: 0.0001142	total: 9.29s	remaining: 1m 48s
# 394:	learn: 0.0001137	total: 9.3s	remaining: 1m 48s
# 395:	learn: 0.0001135	total: 9.32s	remaining: 1m 48s
# 396:	learn: 0.0001133	total: 9.34s	remaining: 1m 48s
# 397:	learn: 0.0001131	total: 9.36s	remaining: 1m 48s
# 398:	learn: 0.0001129	total: 9.37s	remaining: 1m 48s
# 399:	learn: 0.0001125	total: 9.39s	remaining: 1m 48s
# 400:	learn: 0.0001123	total: 9.41s	remaining: 1m 47s
# 401:	learn: 0.0001121	total: 9.43s	remaining: 1m 47s
# 402:	learn: 0.0001115	total: 9.44s	remaining: 1m 47s
# 403:	learn: 0.0001109	total: 9.46s	remaining: 1m 47s
# 404:	learn: 0.0001108	total: 9.48s	remaining: 1m 47s
# 405:	learn: 0.0001106	total: 9.5s	remaining: 1m 47s
# 406:	learn: 0.0001102	total: 9.52s	remaining: 1m 47s
# 407:	learn: 0.0001098	total: 9.54s	remaining: 1m 47s
# 408:	learn: 0.0001095	total: 9.56s	remaining: 1m 47s
# 409:	learn: 0.0001091	total: 9.58s	remaining: 1m 47s
# 410:	learn: 0.0001085	total: 9.59s	remaining: 1m 47s
# 411:	learn: 0.0001081	total: 9.61s	remaining: 1m 47s
# 412:	learn: 0.0001079	total: 9.63s	remaining: 1m 46s
# 413:	learn: 0.0001078	total: 9.64s	remaining: 1m 46s
# 414:	learn: 0.0001073	total: 9.66s	remaining: 1m 46s
# 415:	learn: 0.0001071	total: 9.68s	remaining: 1m 46s
# 416:	learn: 0.0001067	total: 9.7s	remaining: 1m 46s
# 417:	learn: 0.0001063	total: 9.72s	remaining: 1m 46s
# 418:	learn: 0.0001060	total: 9.74s	remaining: 1m 46s
# 419:	learn: 0.0001054	total: 9.75s	remaining: 1m 46s
# 420:	learn: 0.0001047	total: 9.77s	remaining: 1m 46s
# 421:	learn: 0.0001045	total: 9.79s	remaining: 1m 46s
# 422:	learn: 0.0001044	total: 9.8s	remaining: 1m 46s
# 423:	learn: 0.0001042	total: 9.82s	remaining: 1m 46s
# 424:	learn: 0.0001035	total: 9.84s	remaining: 1m 45s
# 425:	learn: 0.0001033	total: 9.86s	remaining: 1m 45s
# 426:	learn: 0.0001031	total: 9.87s	remaining: 1m 45s
# 427:	learn: 0.0001027	total: 9.89s	remaining: 1m 45s
# 428:	learn: 0.0001022	total: 9.92s	remaining: 1m 45s
# 429:	learn: 0.0001018	total: 9.94s	remaining: 1m 45s
# 430:	learn: 0.0001012	total: 9.96s	remaining: 1m 45s
# 431:	learn: 0.0001008	total: 9.99s	remaining: 1m 45s
# 432:	learn: 0.0001007	total: 10s	remaining: 1m 45s
# 433:	learn: 0.0001005	total: 10s	remaining: 1m 45s
# 434:	learn: 0.0001003	total: 10s	remaining: 1m 45s
# 435:	learn: 0.0001001	total: 10.1s	remaining: 1m 45s
# 436:	learn: 0.0001000	total: 10.1s	remaining: 1m 45s
# 437:	learn: 0.0000997	total: 10.1s	remaining: 1m 45s
# 438:	learn: 0.0000995	total: 10.1s	remaining: 1m 45s
# 439:	learn: 0.0000991	total: 10.1s	remaining: 1m 44s
# 440:	learn: 0.0000989	total: 10.1s	remaining: 1m 44s
# 441:	learn: 0.0000988	total: 10.2s	remaining: 1m 44s
# 442:	learn: 0.0000983	total: 10.2s	remaining: 1m 44s
# 443:	learn: 0.0000982	total: 10.2s	remaining: 1m 44s
# 444:	learn: 0.0000980	total: 10.2s	remaining: 1m 44s
# 445:	learn: 0.0000978	total: 10.2s	remaining: 1m 44s
# 446:	learn: 0.0000974	total: 10.3s	remaining: 1m 44s
# 447:	learn: 0.0000973	total: 10.3s	remaining: 1m 44s
# 448:	learn: 0.0000972	total: 10.3s	remaining: 1m 44s
# 449:	learn: 0.0000968	total: 10.3s	remaining: 1m 44s
# 450:	learn: 0.0000964	total: 10.3s	remaining: 1m 44s
# 451:	learn: 0.0000963	total: 10.3s	remaining: 1m 44s
# 452:	learn: 0.0000961	total: 10.4s	remaining: 1m 43s
# 453:	learn: 0.0000959	total: 10.4s	remaining: 1m 43s
# 454:	learn: 0.0000957	total: 10.4s	remaining: 1m 43s
# 455:	learn: 0.0000956	total: 10.4s	remaining: 1m 43s
# 456:	learn: 0.0000953	total: 10.4s	remaining: 1m 43s
# 457:	learn: 0.0000951	total: 10.4s	remaining: 1m 43s
# 458:	learn: 0.0000945	total: 10.5s	remaining: 1m 43s
# 459:	learn: 0.0000944	total: 10.5s	remaining: 1m 43s
# 460:	learn: 0.0000940	total: 10.5s	remaining: 1m 43s
# 461:	learn: 0.0000938	total: 10.5s	remaining: 1m 43s
# 462:	learn: 0.0000936	total: 10.5s	remaining: 1m 43s
# 463:	learn: 0.0000935	total: 10.6s	remaining: 1m 43s
# 464:	learn: 0.0000934	total: 10.6s	remaining: 1m 43s
# 465:	learn: 0.0000932	total: 10.6s	remaining: 1m 43s
# 466:	learn: 0.0000929	total: 10.6s	remaining: 1m 42s
# 467:	learn: 0.0000924	total: 10.6s	remaining: 1m 42s
# 468:	learn: 0.0000923	total: 10.6s	remaining: 1m 42s
# 469:	learn: 0.0000919	total: 10.7s	remaining: 1m 42s
# 470:	learn: 0.0000918	total: 10.7s	remaining: 1m 42s
# 471:	learn: 0.0000916	total: 10.7s	remaining: 1m 42s
# 472:	learn: 0.0000914	total: 10.7s	remaining: 1m 42s
# 473:	learn: 0.0000912	total: 10.7s	remaining: 1m 42s
# 474:	learn: 0.0000911	total: 10.7s	remaining: 1m 42s
# 475:	learn: 0.0000908	total: 10.8s	remaining: 1m 42s
# 476:	learn: 0.0000905	total: 10.8s	remaining: 1m 42s
# 477:	learn: 0.0000903	total: 10.8s	remaining: 1m 42s
# 478:	learn: 0.0000897	total: 10.8s	remaining: 1m 42s
# 479:	learn: 0.0000895	total: 10.8s	remaining: 1m 41s
# 480:	learn: 0.0000890	total: 10.8s	remaining: 1m 41s
# 481:	learn: 0.0000888	total: 10.9s	remaining: 1m 41s
# 482:	learn: 0.0000887	total: 10.9s	remaining: 1m 41s
# 483:	learn: 0.0000886	total: 10.9s	remaining: 1m 41s
# 484:	learn: 0.0000884	total: 10.9s	remaining: 1m 41s
# 485:	learn: 0.0000883	total: 10.9s	remaining: 1m 41s
# 486:	learn: 0.0000881	total: 10.9s	remaining: 1m 41s
# 487:	learn: 0.0000879	total: 11s	remaining: 1m 41s
# 488:	learn: 0.0000877	total: 11s	remaining: 1m 41s
# 489:	learn: 0.0000876	total: 11s	remaining: 1m 41s
# 490:	learn: 0.0000874	total: 11s	remaining: 1m 41s
# 491:	learn: 0.0000872	total: 11s	remaining: 1m 41s
# 492:	learn: 0.0000870	total: 11.1s	remaining: 1m 41s
# 493:	learn: 0.0000869	total: 11.1s	remaining: 1m 41s
# 494:	learn: 0.0000867	total: 11.1s	remaining: 1m 40s
# 495:	learn: 0.0000863	total: 11.1s	remaining: 1m 40s
# 496:	learn: 0.0000862	total: 11.1s	remaining: 1m 40s
# 497:	learn: 0.0000858	total: 11.1s	remaining: 1m 40s
# 498:	learn: 0.0000857	total: 11.2s	remaining: 1m 40s
# 499:	learn: 0.0000855	total: 11.2s	remaining: 1m 40s
# 500:	learn: 0.0000854	total: 11.2s	remaining: 1m 40s
# 501:	learn: 0.0000853	total: 11.2s	remaining: 1m 40s
# 502:	learn: 0.0000848	total: 11.2s	remaining: 1m 40s
# 503:	learn: 0.0000847	total: 11.2s	remaining: 1m 40s
# 504:	learn: 0.0000847	total: 11.3s	remaining: 1m 40s
# 505:	learn: 0.0000845	total: 11.3s	remaining: 1m 40s
# 506:	learn: 0.0000843	total: 11.3s	remaining: 1m 40s
# 507:	learn: 0.0000842	total: 11.3s	remaining: 1m 40s
# 508:	learn: 0.0000838	total: 11.3s	remaining: 1m 39s
# 509:	learn: 0.0000836	total: 11.3s	remaining: 1m 39s
# 510:	learn: 0.0000835	total: 11.4s	remaining: 1m 39s
# 511:	learn: 0.0000833	total: 11.4s	remaining: 1m 39s
# 512:	learn: 0.0000831	total: 11.4s	remaining: 1m 39s
# 513:	learn: 0.0000830	total: 11.4s	remaining: 1m 39s
# 514:	learn: 0.0000829	total: 11.4s	remaining: 1m 39s
# 515:	learn: 0.0000826	total: 11.5s	remaining: 1m 39s
# 516:	learn: 0.0000824	total: 11.5s	remaining: 1m 39s
# 517:	learn: 0.0000822	total: 11.5s	remaining: 1m 39s
# 518:	learn: 0.0000820	total: 11.5s	remaining: 1m 39s
# 519:	learn: 0.0000818	total: 11.5s	remaining: 1m 39s
# 520:	learn: 0.0000817	total: 11.5s	remaining: 1m 39s
# 521:	learn: 0.0000814	total: 11.6s	remaining: 1m 39s
# 522:	learn: 0.0000811	total: 11.6s	remaining: 1m 39s
# 523:	learn: 0.0000810	total: 11.6s	remaining: 1m 39s
# 524:	learn: 0.0000809	total: 11.6s	remaining: 1m 39s
# 525:	learn: 0.0000808	total: 11.6s	remaining: 1m 39s
# 526:	learn: 0.0000804	total: 11.7s	remaining: 1m 38s
# 527:	learn: 0.0000802	total: 11.7s	remaining: 1m 38s
# 528:	learn: 0.0000801	total: 11.7s	remaining: 1m 38s
# 529:	learn: 0.0000800	total: 11.7s	remaining: 1m 38s
# 530:	learn: 0.0000798	total: 11.7s	remaining: 1m 38s
# 531:	learn: 0.0000795	total: 11.7s	remaining: 1m 38s
# 532:	learn: 0.0000794	total: 11.8s	remaining: 1m 38s
# 533:	learn: 0.0000792	total: 11.8s	remaining: 1m 38s
# 534:	learn: 0.0000789	total: 11.8s	remaining: 1m 38s
# 535:	learn: 0.0000788	total: 11.8s	remaining: 1m 38s
# 536:	learn: 0.0000787	total: 11.8s	remaining: 1m 38s
# 537:	learn: 0.0000785	total: 11.9s	remaining: 1m 38s
# 538:	learn: 0.0000784	total: 11.9s	remaining: 1m 38s
# 539:	learn: 0.0000783	total: 11.9s	remaining: 1m 38s
# 540:	learn: 0.0000781	total: 11.9s	remaining: 1m 38s
# 541:	learn: 0.0000779	total: 11.9s	remaining: 1m 38s
# 542:	learn: 0.0000779	total: 11.9s	remaining: 1m 38s
# 543:	learn: 0.0000778	total: 12s	remaining: 1m 37s
# 544:	learn: 0.0000777	total: 12s	remaining: 1m 38s
# 545:	learn: 0.0000775	total: 12s	remaining: 1m 38s
# 546:	learn: 0.0000774	total: 12s	remaining: 1m 37s
# 547:	learn: 0.0000773	total: 12.1s	remaining: 1m 37s
# 548:	learn: 0.0000771	total: 12.1s	remaining: 1m 37s
# 549:	learn: 0.0000769	total: 12.1s	remaining: 1m 37s
# 550:	learn: 0.0000767	total: 12.1s	remaining: 1m 37s
# 551:	learn: 0.0000763	total: 12.1s	remaining: 1m 37s
# 552:	learn: 0.0000760	total: 12.1s	remaining: 1m 37s
# 553:	learn: 0.0000758	total: 12.2s	remaining: 1m 37s
# 554:	learn: 0.0000757	total: 12.2s	remaining: 1m 37s
# 555:	learn: 0.0000756	total: 12.2s	remaining: 1m 37s
# 556:	learn: 0.0000755	total: 12.2s	remaining: 1m 37s
# 557:	learn: 0.0000754	total: 12.2s	remaining: 1m 37s
# 558:	learn: 0.0000751	total: 12.2s	remaining: 1m 37s
# 559:	learn: 0.0000750	total: 12.3s	remaining: 1m 37s
# 560:	learn: 0.0000749	total: 12.3s	remaining: 1m 37s
# 561:	learn: 0.0000748	total: 12.3s	remaining: 1m 37s
# 562:	learn: 0.0000747	total: 12.3s	remaining: 1m 37s
# 563:	learn: 0.0000746	total: 12.3s	remaining: 1m 37s
# 564:	learn: 0.0000743	total: 12.4s	remaining: 1m 37s
# 565:	learn: 0.0000741	total: 12.4s	remaining: 1m 36s
# 566:	learn: 0.0000738	total: 12.4s	remaining: 1m 36s
# 567:	learn: 0.0000736	total: 12.4s	remaining: 1m 36s
# 568:	learn: 0.0000735	total: 12.4s	remaining: 1m 36s
# 569:	learn: 0.0000731	total: 12.4s	remaining: 1m 36s
# 570:	learn: 0.0000730	total: 12.5s	remaining: 1m 36s
# 571:	learn: 0.0000729	total: 12.5s	remaining: 1m 36s
# 572:	learn: 0.0000727	total: 12.5s	remaining: 1m 36s
# 573:	learn: 0.0000726	total: 12.5s	remaining: 1m 36s
# 574:	learn: 0.0000725	total: 12.6s	remaining: 1m 36s
# 575:	learn: 0.0000723	total: 12.6s	remaining: 1m 36s
# 576:	learn: 0.0000721	total: 12.6s	remaining: 1m 36s
# 577:	learn: 0.0000721	total: 12.6s	remaining: 1m 36s
# 578:	learn: 0.0000717	total: 12.6s	remaining: 1m 36s
# 579:	learn: 0.0000715	total: 12.6s	remaining: 1m 36s
# 580:	learn: 0.0000713	total: 12.7s	remaining: 1m 36s
# 581:	learn: 0.0000711	total: 12.7s	remaining: 1m 36s
# 582:	learn: 0.0000709	total: 12.7s	remaining: 1m 36s
# 583:	learn: 0.0000706	total: 12.7s	remaining: 1m 36s
# 584:	learn: 0.0000704	total: 12.8s	remaining: 1m 36s
# 585:	learn: 0.0000703	total: 12.8s	remaining: 1m 36s
# 586:	learn: 0.0000702	total: 12.8s	remaining: 1m 36s
# 587:	learn: 0.0000701	total: 12.8s	remaining: 1m 36s
# 588:	learn: 0.0000699	total: 12.8s	remaining: 1m 36s
# 589:	learn: 0.0000696	total: 12.8s	remaining: 1m 35s
# 590:	learn: 0.0000695	total: 12.9s	remaining: 1m 35s
# 591:	learn: 0.0000691	total: 12.9s	remaining: 1m 35s
# 592:	learn: 0.0000690	total: 12.9s	remaining: 1m 35s
# 593:	learn: 0.0000689	total: 12.9s	remaining: 1m 35s
# 594:	learn: 0.0000688	total: 12.9s	remaining: 1m 35s
# 595:	learn: 0.0000687	total: 12.9s	remaining: 1m 35s
# 596:	learn: 0.0000686	total: 13s	remaining: 1m 35s
# 597:	learn: 0.0000684	total: 13s	remaining: 1m 35s
# 598:	learn: 0.0000683	total: 13s	remaining: 1m 35s
# 599:	learn: 0.0000681	total: 13s	remaining: 1m 35s
# 600:	learn: 0.0000681	total: 13s	remaining: 1m 35s
# 601:	learn: 0.0000680	total: 13.1s	remaining: 1m 35s
# 602:	learn: 0.0000679	total: 13.1s	remaining: 1m 35s
# 603:	learn: 0.0000677	total: 13.1s	remaining: 1m 35s
# 604:	learn: 0.0000676	total: 13.1s	remaining: 1m 35s
# 605:	learn: 0.0000676	total: 13.1s	remaining: 1m 35s
# 606:	learn: 0.0000675	total: 13.1s	remaining: 1m 35s
# 607:	learn: 0.0000674	total: 13.2s	remaining: 1m 35s
# 608:	learn: 0.0000672	total: 13.2s	remaining: 1m 34s
# 609:	learn: 0.0000671	total: 13.2s	remaining: 1m 34s
# 610:	learn: 0.0000671	total: 13.2s	remaining: 1m 34s
# 611:	learn: 0.0000669	total: 13.2s	remaining: 1m 34s
# 612:	learn: 0.0000668	total: 13.2s	remaining: 1m 34s
# 613:	learn: 0.0000667	total: 13.3s	remaining: 1m 34s
# 614:	learn: 0.0000666	total: 13.3s	remaining: 1m 34s
# 615:	learn: 0.0000664	total: 13.3s	remaining: 1m 34s
# 616:	learn: 0.0000661	total: 13.3s	remaining: 1m 34s
# 617:	learn: 0.0000660	total: 13.3s	remaining: 1m 34s
# 618:	learn: 0.0000657	total: 13.3s	remaining: 1m 34s
# 619:	learn: 0.0000656	total: 13.4s	remaining: 1m 34s
# 620:	learn: 0.0000654	total: 13.4s	remaining: 1m 34s
# 621:	learn: 0.0000654	total: 13.4s	remaining: 1m 34s
# 622:	learn: 0.0000652	total: 13.4s	remaining: 1m 34s
# 623:	learn: 0.0000651	total: 13.4s	remaining: 1m 34s
# 624:	learn: 0.0000650	total: 13.5s	remaining: 1m 34s
# 625:	learn: 0.0000649	total: 13.5s	remaining: 1m 34s
# 626:	learn: 0.0000648	total: 13.5s	remaining: 1m 34s
# 627:	learn: 0.0000647	total: 13.5s	remaining: 1m 34s
# 628:	learn: 0.0000646	total: 13.5s	remaining: 1m 34s
# 629:	learn: 0.0000645	total: 13.6s	remaining: 1m 34s
# 630:	learn: 0.0000643	total: 13.6s	remaining: 1m 33s
# 631:	learn: 0.0000642	total: 13.6s	remaining: 1m 33s
# 632:	learn: 0.0000642	total: 13.6s	remaining: 1m 33s
# 633:	learn: 0.0000641	total: 13.6s	remaining: 1m 33s
# 634:	learn: 0.0000640	total: 13.6s	remaining: 1m 33s
# 635:	learn: 0.0000640	total: 13.7s	remaining: 1m 33s
# 636:	learn: 0.0000638	total: 13.7s	remaining: 1m 33s
# 637:	learn: 0.0000637	total: 13.7s	remaining: 1m 33s
# 638:	learn: 0.0000636	total: 13.7s	remaining: 1m 33s
# 639:	learn: 0.0000635	total: 13.7s	remaining: 1m 33s
# 640:	learn: 0.0000635	total: 13.7s	remaining: 1m 33s
# 641:	learn: 0.0000632	total: 13.8s	remaining: 1m 33s
# 642:	learn: 0.0000631	total: 13.8s	remaining: 1m 33s
# 643:	learn: 0.0000630	total: 13.8s	remaining: 1m 33s
# 644:	learn: 0.0000630	total: 13.8s	remaining: 1m 33s
# 645:	learn: 0.0000628	total: 13.8s	remaining: 1m 33s
# 646:	learn: 0.0000626	total: 13.9s	remaining: 1m 33s
# 647:	learn: 0.0000625	total: 13.9s	remaining: 1m 33s
# 648:	learn: 0.0000622	total: 13.9s	remaining: 1m 33s
# 649:	learn: 0.0000621	total: 13.9s	remaining: 1m 33s
# 650:	learn: 0.0000621	total: 13.9s	remaining: 1m 33s
# 651:	learn: 0.0000620	total: 14s	remaining: 1m 33s
# 652:	learn: 0.0000620	total: 14s	remaining: 1m 33s
# 653:	learn: 0.0000619	total: 14s	remaining: 1m 32s
# 654:	learn: 0.0000619	total: 14s	remaining: 1m 32s
# 655:	learn: 0.0000616	total: 14s	remaining: 1m 32s
# 656:	learn: 0.0000614	total: 14.1s	remaining: 1m 32s
# 657:	learn: 0.0000613	total: 14.1s	remaining: 1m 32s
# 658:	learn: 0.0000612	total: 14.1s	remaining: 1m 32s
# 659:	learn: 0.0000609	total: 14.1s	remaining: 1m 32s
# 660:	learn: 0.0000607	total: 14.1s	remaining: 1m 32s
# 661:	learn: 0.0000606	total: 14.2s	remaining: 1m 32s
# 662:	learn: 0.0000603	total: 14.2s	remaining: 1m 32s
# 663:	learn: 0.0000602	total: 14.2s	remaining: 1m 32s
# 664:	learn: 0.0000602	total: 14.2s	remaining: 1m 32s
# 665:	learn: 0.0000601	total: 14.2s	remaining: 1m 32s
# 666:	learn: 0.0000600	total: 14.2s	remaining: 1m 32s
# 667:	learn: 0.0000600	total: 14.3s	remaining: 1m 32s
# 668:	learn: 0.0000596	total: 14.3s	remaining: 1m 32s
# 669:	learn: 0.0000596	total: 14.3s	remaining: 1m 32s
# 670:	learn: 0.0000595	total: 14.3s	remaining: 1m 32s
# 671:	learn: 0.0000595	total: 14.3s	remaining: 1m 32s
# 672:	learn: 0.0000594	total: 14.4s	remaining: 1m 32s
# 673:	learn: 0.0000593	total: 14.4s	remaining: 1m 32s
# 674:	learn: 0.0000592	total: 14.4s	remaining: 1m 32s
# 675:	learn: 0.0000591	total: 14.4s	remaining: 1m 32s
# 676:	learn: 0.0000590	total: 14.4s	remaining: 1m 32s
# 677:	learn: 0.0000588	total: 14.4s	remaining: 1m 32s
# 678:	learn: 0.0000588	total: 14.5s	remaining: 1m 32s
# 679:	learn: 0.0000586	total: 14.5s	remaining: 1m 32s
# 680:	learn: 0.0000583	total: 14.5s	remaining: 1m 32s
# 681:	learn: 0.0000582	total: 14.5s	remaining: 1m 31s
# 682:	learn: 0.0000581	total: 14.5s	remaining: 1m 31s
# 683:	learn: 0.0000578	total: 14.6s	remaining: 1m 31s
# 684:	learn: 0.0000577	total: 14.6s	remaining: 1m 31s
# 685:	learn: 0.0000575	total: 14.6s	remaining: 1m 31s
# 686:	learn: 0.0000574	total: 14.6s	remaining: 1m 31s
# 687:	learn: 0.0000573	total: 14.6s	remaining: 1m 31s
# 688:	learn: 0.0000572	total: 14.7s	remaining: 1m 31s
# 689:	learn: 0.0000572	total: 14.7s	remaining: 1m 31s
# 690:	learn: 0.0000570	total: 14.7s	remaining: 1m 31s
# 691:	learn: 0.0000569	total: 14.7s	remaining: 1m 31s
# 692:	learn: 0.0000569	total: 14.7s	remaining: 1m 31s
# 693:	learn: 0.0000568	total: 14.7s	remaining: 1m 31s
# 694:	learn: 0.0000568	total: 14.8s	remaining: 1m 31s
# 695:	learn: 0.0000566	total: 14.8s	remaining: 1m 31s
# 696:	learn: 0.0000565	total: 14.8s	remaining: 1m 31s
# 697:	learn: 0.0000564	total: 14.8s	remaining: 1m 31s
# 698:	learn: 0.0000562	total: 14.8s	remaining: 1m 31s
# 699:	learn: 0.0000562	total: 14.9s	remaining: 1m 31s
# 700:	learn: 0.0000560	total: 14.9s	remaining: 1m 31s
# 701:	learn: 0.0000559	total: 14.9s	remaining: 1m 31s
# 702:	learn: 0.0000557	total: 14.9s	remaining: 1m 31s
# 703:	learn: 0.0000556	total: 14.9s	remaining: 1m 31s
# 704:	learn: 0.0000555	total: 14.9s	remaining: 1m 31s
# 705:	learn: 0.0000554	total: 15s	remaining: 1m 31s
# 706:	learn: 0.0000553	total: 15s	remaining: 1m 30s
# 707:	learn: 0.0000552	total: 15s	remaining: 1m 30s
# 708:	learn: 0.0000551	total: 15s	remaining: 1m 30s
# 709:	learn: 0.0000550	total: 15s	remaining: 1m 30s
# 710:	learn: 0.0000549	total: 15.1s	remaining: 1m 30s
# 711:	learn: 0.0000548	total: 15.1s	remaining: 1m 30s
# 712:	learn: 0.0000547	total: 15.1s	remaining: 1m 30s
# 713:	learn: 0.0000545	total: 15.1s	remaining: 1m 30s
# 714:	learn: 0.0000545	total: 15.1s	remaining: 1m 30s
# 715:	learn: 0.0000544	total: 15.2s	remaining: 1m 30s
# 716:	learn: 0.0000544	total: 15.2s	remaining: 1m 30s
# 717:	learn: 0.0000543	total: 15.2s	remaining: 1m 30s
# 718:	learn: 0.0000542	total: 15.2s	remaining: 1m 30s
# 719:	learn: 0.0000542	total: 15.2s	remaining: 1m 30s
# 720:	learn: 0.0000541	total: 15.2s	remaining: 1m 30s
# 721:	learn: 0.0000540	total: 15.3s	remaining: 1m 30s
# 722:	learn: 0.0000540	total: 15.3s	remaining: 1m 30s
# 723:	learn: 0.0000538	total: 15.3s	remaining: 1m 30s
# 724:	learn: 0.0000538	total: 15.3s	remaining: 1m 30s
# 725:	learn: 0.0000537	total: 15.3s	remaining: 1m 30s
# 726:	learn: 0.0000537	total: 15.4s	remaining: 1m 30s
# 727:	learn: 0.0000536	total: 15.4s	remaining: 1m 30s
# 728:	learn: 0.0000536	total: 15.4s	remaining: 1m 30s
# 729:	learn: 0.0000535	total: 15.4s	remaining: 1m 30s
# 730:	learn: 0.0000535	total: 15.4s	remaining: 1m 30s
# 731:	learn: 0.0000534	total: 15.4s	remaining: 1m 30s
# 732:	learn: 0.0000534	total: 15.5s	remaining: 1m 30s
# 733:	learn: 0.0000533	total: 15.5s	remaining: 1m 30s
# 734:	learn: 0.0000532	total: 15.5s	remaining: 1m 29s
# 735:	learn: 0.0000530	total: 15.5s	remaining: 1m 29s
# 736:	learn: 0.0000530	total: 15.5s	remaining: 1m 29s
# 737:	learn: 0.0000529	total: 15.5s	remaining: 1m 29s
# 738:	learn: 0.0000528	total: 15.6s	remaining: 1m 29s
# 739:	learn: 0.0000527	total: 15.6s	remaining: 1m 29s
# 740:	learn: 0.0000525	total: 15.6s	remaining: 1m 29s
# 741:	learn: 0.0000524	total: 15.6s	remaining: 1m 29s
# 742:	learn: 0.0000524	total: 15.6s	remaining: 1m 29s
# 743:	learn: 0.0000523	total: 15.7s	remaining: 1m 29s
# 744:	learn: 0.0000522	total: 15.7s	remaining: 1m 29s
# 745:	learn: 0.0000522	total: 15.7s	remaining: 1m 29s
# 746:	learn: 0.0000521	total: 15.7s	remaining: 1m 29s
# 747:	learn: 0.0000519	total: 15.7s	remaining: 1m 29s
# 748:	learn: 0.0000519	total: 15.7s	remaining: 1m 29s
# 749:	learn: 0.0000517	total: 15.8s	remaining: 1m 29s
# 750:	learn: 0.0000517	total: 15.8s	remaining: 1m 29s
# 751:	learn: 0.0000516	total: 15.8s	remaining: 1m 29s
# 752:	learn: 0.0000515	total: 15.8s	remaining: 1m 29s
# 753:	learn: 0.0000515	total: 15.8s	remaining: 1m 29s
# 754:	learn: 0.0000514	total: 15.8s	remaining: 1m 29s
# 755:	learn: 0.0000514	total: 15.9s	remaining: 1m 29s
# 756:	learn: 0.0000512	total: 15.9s	remaining: 1m 28s
# 757:	learn: 0.0000511	total: 15.9s	remaining: 1m 28s
# 758:	learn: 0.0000509	total: 15.9s	remaining: 1m 28s
# 759:	learn: 0.0000508	total: 15.9s	remaining: 1m 28s
# 760:	learn: 0.0000507	total: 15.9s	remaining: 1m 28s
# 761:	learn: 0.0000506	total: 16s	remaining: 1m 28s
# 762:	learn: 0.0000506	total: 16s	remaining: 1m 28s
# 763:	learn: 0.0000505	total: 16s	remaining: 1m 28s
# 764:	learn: 0.0000504	total: 16s	remaining: 1m 28s
# 765:	learn: 0.0000503	total: 16s	remaining: 1m 28s
# 766:	learn: 0.0000501	total: 16.1s	remaining: 1m 28s
# 767:	learn: 0.0000500	total: 16.1s	remaining: 1m 28s
# 768:	learn: 0.0000499	total: 16.1s	remaining: 1m 28s
# 769:	learn: 0.0000498	total: 16.1s	remaining: 1m 28s
# 770:	learn: 0.0000498	total: 16.1s	remaining: 1m 28s
# 771:	learn: 0.0000496	total: 16.2s	remaining: 1m 28s
# 772:	learn: 0.0000495	total: 16.2s	remaining: 1m 28s
# 773:	learn: 0.0000495	total: 16.2s	remaining: 1m 28s
# 774:	learn: 0.0000495	total: 16.2s	remaining: 1m 28s
# 775:	learn: 0.0000494	total: 16.2s	remaining: 1m 28s
# 776:	learn: 0.0000494	total: 16.2s	remaining: 1m 28s
# 777:	learn: 0.0000493	total: 16.3s	remaining: 1m 28s
# 778:	learn: 0.0000493	total: 16.3s	remaining: 1m 28s
# 779:	learn: 0.0000492	total: 16.3s	remaining: 1m 28s
# 780:	learn: 0.0000490	total: 16.3s	remaining: 1m 28s
# 781:	learn: 0.0000489	total: 16.3s	remaining: 1m 28s
# 782:	learn: 0.0000489	total: 16.3s	remaining: 1m 28s
# 783:	learn: 0.0000488	total: 16.4s	remaining: 1m 27s
# 784:	learn: 0.0000488	total: 16.4s	remaining: 1m 27s
# 785:	learn: 0.0000487	total: 16.4s	remaining: 1m 27s
# 786:	learn: 0.0000486	total: 16.4s	remaining: 1m 27s
# 787:	learn: 0.0000485	total: 16.4s	remaining: 1m 27s
# 788:	learn: 0.0000485	total: 16.5s	remaining: 1m 27s
# 789:	learn: 0.0000483	total: 16.5s	remaining: 1m 27s
# 790:	learn: 0.0000482	total: 16.5s	remaining: 1m 27s
# 791:	learn: 0.0000481	total: 16.5s	remaining: 1m 27s
# 792:	learn: 0.0000479	total: 16.5s	remaining: 1m 27s
# 793:	learn: 0.0000479	total: 16.6s	remaining: 1m 27s
# 794:	learn: 0.0000478	total: 16.6s	remaining: 1m 27s
# 795:	learn: 0.0000478	total: 16.6s	remaining: 1m 27s
# 796:	learn: 0.0000477	total: 16.6s	remaining: 1m 27s
# 797:	learn: 0.0000476	total: 16.6s	remaining: 1m 27s
# 798:	learn: 0.0000476	total: 16.7s	remaining: 1m 27s
# 799:	learn: 0.0000475	total: 16.7s	remaining: 1m 27s
# 800:	learn: 0.0000475	total: 16.7s	remaining: 1m 27s
# 801:	learn: 0.0000474	total: 16.7s	remaining: 1m 27s
# 802:	learn: 0.0000474	total: 16.7s	remaining: 1m 27s
# 803:	learn: 0.0000473	total: 16.7s	remaining: 1m 27s
# 804:	learn: 0.0000473	total: 16.8s	remaining: 1m 27s
# 805:	learn: 0.0000472	total: 16.8s	remaining: 1m 27s
# 806:	learn: 0.0000472	total: 16.8s	remaining: 1m 27s
# 807:	learn: 0.0000472	total: 16.8s	remaining: 1m 27s
# 808:	learn: 0.0000471	total: 16.9s	remaining: 1m 27s
# 809:	learn: 0.0000471	total: 16.9s	remaining: 1m 27s
# 810:	learn: 0.0000470	total: 16.9s	remaining: 1m 27s
# 811:	learn: 0.0000470	total: 17s	remaining: 1m 27s
# 812:	learn: 0.0000468	total: 17s	remaining: 1m 27s
# 813:	learn: 0.0000465	total: 17s	remaining: 1m 27s
# 814:	learn: 0.0000464	total: 17.1s	remaining: 1m 27s
# 815:	learn: 0.0000464	total: 17.1s	remaining: 1m 27s
# 816:	learn: 0.0000463	total: 17.1s	remaining: 1m 27s
# 817:	learn: 0.0000463	total: 17.2s	remaining: 1m 27s
# 818:	learn: 0.0000463	total: 17.2s	remaining: 1m 27s
# 819:	learn: 0.0000460	total: 17.2s	remaining: 1m 27s
# 820:	learn: 0.0000460	total: 17.3s	remaining: 1m 27s
# 821:	learn: 0.0000458	total: 17.3s	remaining: 1m 27s
# 822:	learn: 0.0000457	total: 17.3s	remaining: 1m 28s
# 823:	learn: 0.0000456	total: 17.4s	remaining: 1m 28s
# 824:	learn: 0.0000456	total: 17.4s	remaining: 1m 28s
# 825:	learn: 0.0000455	total: 17.4s	remaining: 1m 28s
# 826:	learn: 0.0000455	total: 17.5s	remaining: 1m 28s
# 827:	learn: 0.0000454	total: 17.5s	remaining: 1m 28s
# 828:	learn: 0.0000453	total: 17.5s	remaining: 1m 28s
# 829:	learn: 0.0000452	total: 17.6s	remaining: 1m 28s
# 830:	learn: 0.0000451	total: 17.6s	remaining: 1m 28s
# 831:	learn: 0.0000451	total: 17.6s	remaining: 1m 28s
# 832:	learn: 0.0000450	total: 17.7s	remaining: 1m 28s
# 833:	learn: 0.0000449	total: 17.7s	remaining: 1m 28s
# 834:	learn: 0.0000448	total: 17.7s	remaining: 1m 28s
# 835:	learn: 0.0000447	total: 17.7s	remaining: 1m 28s
# 836:	learn: 0.0000446	total: 17.8s	remaining: 1m 28s
# 837:	learn: 0.0000446	total: 17.8s	remaining: 1m 28s
# 838:	learn: 0.0000445	total: 17.8s	remaining: 1m 28s
# 839:	learn: 0.0000445	total: 17.9s	remaining: 1m 28s
# 840:	learn: 0.0000444	total: 17.9s	remaining: 1m 28s
# 841:	learn: 0.0000443	total: 17.9s	remaining: 1m 28s
# 842:	learn: 0.0000443	total: 18s	remaining: 1m 28s
# 843:	learn: 0.0000443	total: 18s	remaining: 1m 28s
# 844:	learn: 0.0000442	total: 18s	remaining: 1m 28s
# 845:	learn: 0.0000441	total: 18.1s	remaining: 1m 28s
# 846:	learn: 0.0000440	total: 18.1s	remaining: 1m 28s
# 847:	learn: 0.0000439	total: 18.2s	remaining: 1m 28s
# 848:	learn: 0.0000438	total: 18.2s	remaining: 1m 29s
# 849:	learn: 0.0000436	total: 18.2s	remaining: 1m 29s
# 850:	learn: 0.0000436	total: 18.3s	remaining: 1m 29s
# 851:	learn: 0.0000434	total: 18.3s	remaining: 1m 29s
# 852:	learn: 0.0000433	total: 18.4s	remaining: 1m 29s
# 853:	learn: 0.0000432	total: 18.4s	remaining: 1m 29s
# 854:	learn: 0.0000432	total: 18.4s	remaining: 1m 29s
# 855:	learn: 0.0000432	total: 18.5s	remaining: 1m 29s
# 856:	learn: 0.0000431	total: 18.5s	remaining: 1m 29s
# 857:	learn: 0.0000431	total: 18.5s	remaining: 1m 29s
# 858:	learn: 0.0000430	total: 18.6s	remaining: 1m 29s
# 859:	learn: 0.0000430	total: 18.6s	remaining: 1m 29s
# 860:	learn: 0.0000429	total: 18.6s	remaining: 1m 29s
# 861:	learn: 0.0000429	total: 18.7s	remaining: 1m 29s
# 862:	learn: 0.0000428	total: 18.7s	remaining: 1m 29s
# 863:	learn: 0.0000427	total: 18.7s	remaining: 1m 29s
# 864:	learn: 0.0000426	total: 18.8s	remaining: 1m 29s
# 865:	learn: 0.0000425	total: 18.8s	remaining: 1m 29s
# 866:	learn: 0.0000424	total: 18.8s	remaining: 1m 29s
# 867:	learn: 0.0000424	total: 18.9s	remaining: 1m 29s
# 868:	learn: 0.0000423	total: 18.9s	remaining: 1m 29s
# 869:	learn: 0.0000421	total: 18.9s	remaining: 1m 29s
# 870:	learn: 0.0000420	total: 19s	remaining: 1m 30s
# 871:	learn: 0.0000420	total: 19s	remaining: 1m 30s
# 872:	learn: 0.0000419	total: 19.1s	remaining: 1m 30s
# 873:	learn: 0.0000419	total: 19.1s	remaining: 1m 30s
# 874:	learn: 0.0000418	total: 19.1s	remaining: 1m 30s
# 875:	learn: 0.0000417	total: 19.2s	remaining: 1m 30s
# 876:	learn: 0.0000415	total: 19.2s	remaining: 1m 30s
# 877:	learn: 0.0000415	total: 19.2s	remaining: 1m 30s
# 878:	learn: 0.0000414	total: 19.3s	remaining: 1m 30s
# 879:	learn: 0.0000413	total: 19.3s	remaining: 1m 30s
# 880:	learn: 0.0000413	total: 19.4s	remaining: 1m 30s
# 881:	learn: 0.0000411	total: 19.4s	remaining: 1m 30s
# 882:	learn: 0.0000411	total: 19.4s	remaining: 1m 30s
# 883:	learn: 0.0000410	total: 19.5s	remaining: 1m 30s
# 884:	learn: 0.0000410	total: 19.5s	remaining: 1m 30s
# 885:	learn: 0.0000409	total: 19.5s	remaining: 1m 30s
# 886:	learn: 0.0000408	total: 19.6s	remaining: 1m 30s
# 887:	learn: 0.0000407	total: 19.6s	remaining: 1m 30s
# 888:	learn: 0.0000407	total: 19.6s	remaining: 1m 30s
# 889:	learn: 0.0000406	total: 19.7s	remaining: 1m 30s
# 890:	learn: 0.0000405	total: 19.7s	remaining: 1m 30s
# 891:	learn: 0.0000405	total: 19.7s	remaining: 1m 30s
# 892:	learn: 0.0000404	total: 19.8s	remaining: 1m 30s
# 893:	learn: 0.0000404	total: 19.8s	remaining: 1m 31s
# 894:	learn: 0.0000403	total: 19.9s	remaining: 1m 31s
# 895:	learn: 0.0000402	total: 19.9s	remaining: 1m 31s
# 896:	learn: 0.0000402	total: 19.9s	remaining: 1m 31s
# 897:	learn: 0.0000401	total: 20s	remaining: 1m 31s
# 898:	learn: 0.0000400	total: 20s	remaining: 1m 31s
# 899:	learn: 0.0000399	total: 20s	remaining: 1m 31s
# 900:	learn: 0.0000398	total: 20.1s	remaining: 1m 31s
# 901:	learn: 0.0000398	total: 20.1s	remaining: 1m 31s
# 902:	learn: 0.0000397	total: 20.2s	remaining: 1m 31s
# 903:	learn: 0.0000397	total: 20.2s	remaining: 1m 31s
# 904:	learn: 0.0000395	total: 20.2s	remaining: 1m 31s
# 905:	learn: 0.0000394	total: 20.3s	remaining: 1m 31s
# 906:	learn: 0.0000393	total: 20.3s	remaining: 1m 31s
# 907:	learn: 0.0000392	total: 20.3s	remaining: 1m 31s
# 908:	learn: 0.0000392	total: 20.4s	remaining: 1m 31s
# 909:	learn: 0.0000392	total: 20.4s	remaining: 1m 31s
# ...
# 4705:	learn: 0.0000002	total: 1m 43s	remaining: 6.5s
# 4706:	learn: 0.0000002	total: 1m 43s	remaining: 6.47s
# 4707:	learn: 0.0000002	total: 1m 44s	remaining: 6.45s
# 4708:	learn: 0.0000002	total: 1m 44s	remaining: 6.43s
# 4709:	learn: 0.0000002	total: 1m 44s	remaining: 6.41s
# 4710:	learn: 0.0000002	total: 1m 44s	remaining: 6.38s
# 4711:	learn: 0.0000002	total: 1m 44s	remaining: 6.36s
# 4712:	learn: 0.0000002	total: 1m 44s	remaining: 6.34s
# 4713:	learn: 0.0000002	total: 1m 44s	remaining: 6.32s
# 4714:	learn: 0.0000002	total: 1m 44s	remaining: 6.29s
# 4715:	learn: 0.0000002	total: 1m 44s	remaining: 6.27s
# 4716:	learn: 0.0000002	total: 1m 44s	remaining: 6.25s
# 4717:	learn: 0.0000002	total: 1m 44s	remaining: 6.23s
# 4718:	learn: 0.0000002	total: 1m 44s	remaining: 6.2s
# 4719:	learn: 0.0000002	total: 1m 44s	remaining: 6.18s
# 4720:	learn: 0.0000002	total: 1m 44s	remaining: 6.16s
# 4721:	learn: 0.0000002	total: 1m 44s	remaining: 6.14s
# 4722:	learn: 0.0000002	total: 1m 44s	remaining: 6.11s
# 4723:	learn: 0.0000002	total: 1m 44s	remaining: 6.09s
# 4724:	learn: 0.0000002	total: 1m 44s	remaining: 6.07s
# 4725:	learn: 0.0000002	total: 1m 44s	remaining: 6.05s
# 4726:	learn: 0.0000002	total: 1m 44s	remaining: 6.03s
# 4727:	learn: 0.0000002	total: 1m 44s	remaining: 6s
# 4728:	learn: 0.0000002	total: 1m 44s	remaining: 5.98s
# 4729:	learn: 0.0000002	total: 1m 44s	remaining: 5.96s
# 4730:	learn: 0.0000002	total: 1m 44s	remaining: 5.94s
# 4731:	learn: 0.0000002	total: 1m 44s	remaining: 5.91s
# 4732:	learn: 0.0000002	total: 1m 44s	remaining: 5.89s
# 4733:	learn: 0.0000002	total: 1m 44s	remaining: 5.87s
# 4734:	learn: 0.0000002	total: 1m 44s	remaining: 5.85s
# 4735:	learn: 0.0000002	total: 1m 44s	remaining: 5.82s
# 4736:	learn: 0.0000002	total: 1m 44s	remaining: 5.8s
# 4737:	learn: 0.0000002	total: 1m 44s	remaining: 5.78s
# 4738:	learn: 0.0000002	total: 1m 44s	remaining: 5.76s
# 4739:	learn: 0.0000002	total: 1m 44s	remaining: 5.74s
# 4740:	learn: 0.0000002	total: 1m 44s	remaining: 5.71s
# 4741:	learn: 0.0000002	total: 1m 44s	remaining: 5.69s
# 4742:	learn: 0.0000002	total: 1m 44s	remaining: 5.67s
# 4743:	learn: 0.0000002	total: 1m 44s	remaining: 5.65s
# 4744:	learn: 0.0000002	total: 1m 44s	remaining: 5.62s
# 4745:	learn: 0.0000002	total: 1m 44s	remaining: 5.6s
# 4746:	learn: 0.0000002	total: 1m 44s	remaining: 5.58s
# 4747:	learn: 0.0000002	total: 1m 44s	remaining: 5.56s
# 4748:	learn: 0.0000002	total: 1m 44s	remaining: 5.54s
# 4749:	learn: 0.0000002	total: 1m 44s	remaining: 5.51s
# 4750:	learn: 0.0000002	total: 1m 44s	remaining: 5.49s
# 4751:	learn: 0.0000002	total: 1m 44s	remaining: 5.47s
# 4752:	learn: 0.0000002	total: 1m 44s	remaining: 5.45s
# 4753:	learn: 0.0000002	total: 1m 44s	remaining: 5.42s
# 4754:	learn: 0.0000002	total: 1m 44s	remaining: 5.4s
# 4755:	learn: 0.0000002	total: 1m 44s	remaining: 5.38s
# 4756:	learn: 0.0000002	total: 1m 44s	remaining: 5.36s
# 4757:	learn: 0.0000002	total: 1m 44s	remaining: 5.33s
# 4758:	learn: 0.0000002	total: 1m 44s	remaining: 5.31s
# 4759:	learn: 0.0000002	total: 1m 44s	remaining: 5.29s
# 4760:	learn: 0.0000002	total: 1m 44s	remaining: 5.27s
# 4761:	learn: 0.0000002	total: 1m 44s	remaining: 5.25s
# 4762:	learn: 0.0000002	total: 1m 44s	remaining: 5.22s
# 4763:	learn: 0.0000002	total: 1m 45s	remaining: 5.2s
# 4764:	learn: 0.0000002	total: 1m 45s	remaining: 5.18s
# 4765:	learn: 0.0000002	total: 1m 45s	remaining: 5.16s
# 4766:	learn: 0.0000002	total: 1m 45s	remaining: 5.13s
# 4767:	learn: 0.0000002	total: 1m 45s	remaining: 5.11s
# 4768:	learn: 0.0000002	total: 1m 45s	remaining: 5.09s
# 4769:	learn: 0.0000002	total: 1m 45s	remaining: 5.07s
# 4770:	learn: 0.0000002	total: 1m 45s	remaining: 5.05s
# 4771:	learn: 0.0000002	total: 1m 45s	remaining: 5.02s
# 4772:	learn: 0.0000002	total: 1m 45s	remaining: 5s
# 4773:	learn: 0.0000002	total: 1m 45s	remaining: 4.98s
# 4774:	learn: 0.0000002	total: 1m 45s	remaining: 4.96s
# 4775:	learn: 0.0000002	total: 1m 45s	remaining: 4.94s
# 4776:	learn: 0.0000002	total: 1m 45s	remaining: 4.91s
# 4777:	learn: 0.0000002	total: 1m 45s	remaining: 4.89s
# 4778:	learn: 0.0000002	total: 1m 45s	remaining: 4.87s
# 4779:	learn: 0.0000002	total: 1m 45s	remaining: 4.85s
# 4780:	learn: 0.0000002	total: 1m 45s	remaining: 4.83s
# 4781:	learn: 0.0000002	total: 1m 45s	remaining: 4.8s
# 4782:	learn: 0.0000002	total: 1m 45s	remaining: 4.78s
# 4783:	learn: 0.0000002	total: 1m 45s	remaining: 4.76s
# 4784:	learn: 0.0000002	total: 1m 45s	remaining: 4.74s
# 4785:	learn: 0.0000002	total: 1m 45s	remaining: 4.71s
# 4786:	learn: 0.0000002	total: 1m 45s	remaining: 4.69s
# 4787:	learn: 0.0000002	total: 1m 45s	remaining: 4.67s
# 4788:	learn: 0.0000002	total: 1m 45s	remaining: 4.65s
# 4789:	learn: 0.0000002	total: 1m 45s	remaining: 4.63s
# 4790:	learn: 0.0000002	total: 1m 45s	remaining: 4.6s
# 4791:	learn: 0.0000002	total: 1m 45s	remaining: 4.58s
# 4792:	learn: 0.0000002	total: 1m 45s	remaining: 4.56s
# 4793:	learn: 0.0000002	total: 1m 45s	remaining: 4.54s
# 4794:	learn: 0.0000002	total: 1m 45s	remaining: 4.51s
# 4795:	learn: 0.0000002	total: 1m 45s	remaining: 4.49s
# 4796:	learn: 0.0000002	total: 1m 45s	remaining: 4.47s
# 4797:	learn: 0.0000002	total: 1m 45s	remaining: 4.45s
# 4798:	learn: 0.0000002	total: 1m 45s	remaining: 4.43s
# 4799:	learn: 0.0000002	total: 1m 45s	remaining: 4.4s
# 4800:	learn: 0.0000002	total: 1m 45s	remaining: 4.38s
# 4801:	learn: 0.0000002	total: 1m 45s	remaining: 4.36s
# 4802:	learn: 0.0000002	total: 1m 45s	remaining: 4.34s
# 4803:	learn: 0.0000002	total: 1m 45s	remaining: 4.32s
# 4804:	learn: 0.0000002	total: 1m 45s	remaining: 4.29s
# 4805:	learn: 0.0000002	total: 1m 45s	remaining: 4.27s
# 4806:	learn: 0.0000002	total: 1m 45s	remaining: 4.25s
# 4807:	learn: 0.0000002	total: 1m 45s	remaining: 4.23s
# 4808:	learn: 0.0000002	total: 1m 45s	remaining: 4.21s
# 4809:	learn: 0.0000002	total: 1m 45s	remaining: 4.19s
# 4810:	learn: 0.0000002	total: 1m 46s	remaining: 4.16s
# 4811:	learn: 0.0000002	total: 1m 46s	remaining: 4.14s
# 4812:	learn: 0.0000002	total: 1m 46s	remaining: 4.12s
# 4813:	learn: 0.0000002	total: 1m 46s	remaining: 4.1s
# 4814:	learn: 0.0000002	total: 1m 46s	remaining: 4.08s
# 4815:	learn: 0.0000002	total: 1m 46s	remaining: 4.06s
# 4816:	learn: 0.0000002	total: 1m 46s	remaining: 4.03s
# 4817:	learn: 0.0000002	total: 1m 46s	remaining: 4.01s
# 4818:	learn: 0.0000002	total: 1m 46s	remaining: 3.99s
# 4819:	learn: 0.0000002	total: 1m 46s	remaining: 3.97s
# 4820:	learn: 0.0000002	total: 1m 46s	remaining: 3.95s
# 4821:	learn: 0.0000002	total: 1m 46s	remaining: 3.93s
# 4822:	learn: 0.0000002	total: 1m 46s	remaining: 3.91s
# 4823:	learn: 0.0000002	total: 1m 46s	remaining: 3.88s
# 4824:	learn: 0.0000002	total: 1m 46s	remaining: 3.86s
# 4825:	learn: 0.0000002	total: 1m 46s	remaining: 3.84s
# 4826:	learn: 0.0000002	total: 1m 46s	remaining: 3.82s
# 4827:	learn: 0.0000002	total: 1m 46s	remaining: 3.8s
# 4828:	learn: 0.0000002	total: 1m 46s	remaining: 3.78s
# 4829:	learn: 0.0000002	total: 1m 46s	remaining: 3.75s
# 4830:	learn: 0.0000002	total: 1m 46s	remaining: 3.73s
# 4831:	learn: 0.0000002	total: 1m 46s	remaining: 3.71s
# 4832:	learn: 0.0000002	total: 1m 46s	remaining: 3.69s
# 4833:	learn: 0.0000002	total: 1m 46s	remaining: 3.67s
# 4834:	learn: 0.0000002	total: 1m 46s	remaining: 3.65s
# 4835:	learn: 0.0000002	total: 1m 46s	remaining: 3.62s
# 4836:	learn: 0.0000002	total: 1m 46s	remaining: 3.6s
# 4837:	learn: 0.0000002	total: 1m 46s	remaining: 3.58s
# 4838:	learn: 0.0000002	total: 1m 47s	remaining: 3.56s
# 4839:	learn: 0.0000002	total: 1m 47s	remaining: 3.54s
# 4840:	learn: 0.0000002	total: 1m 47s	remaining: 3.52s
# 4841:	learn: 0.0000002	total: 1m 47s	remaining: 3.5s
# 4842:	learn: 0.0000002	total: 1m 47s	remaining: 3.47s
# 4843:	learn: 0.0000002	total: 1m 47s	remaining: 3.45s
# 4844:	learn: 0.0000002	total: 1m 47s	remaining: 3.43s
# 4845:	learn: 0.0000002	total: 1m 47s	remaining: 3.41s
# 4846:	learn: 0.0000002	total: 1m 47s	remaining: 3.39s
# 4847:	learn: 0.0000002	total: 1m 47s	remaining: 3.37s
# 4848:	learn: 0.0000002	total: 1m 47s	remaining: 3.34s
# 4849:	learn: 0.0000002	total: 1m 47s	remaining: 3.32s
# 4850:	learn: 0.0000002	total: 1m 47s	remaining: 3.3s
# 4851:	learn: 0.0000002	total: 1m 47s	remaining: 3.28s
# 4852:	learn: 0.0000002	total: 1m 47s	remaining: 3.26s
# 4853:	learn: 0.0000002	total: 1m 47s	remaining: 3.23s
# 4854:	learn: 0.0000002	total: 1m 47s	remaining: 3.21s
# 4855:	learn: 0.0000002	total: 1m 47s	remaining: 3.19s
# 4856:	learn: 0.0000002	total: 1m 47s	remaining: 3.17s
# 4857:	learn: 0.0000002	total: 1m 47s	remaining: 3.15s
# 4858:	learn: 0.0000002	total: 1m 47s	remaining: 3.13s
# 4859:	learn: 0.0000002	total: 1m 47s	remaining: 3.1s
# 4860:	learn: 0.0000002	total: 1m 47s	remaining: 3.08s
# 4861:	learn: 0.0000002	total: 1m 47s	remaining: 3.06s
# 4862:	learn: 0.0000002	total: 1m 47s	remaining: 3.04s
# 4863:	learn: 0.0000002	total: 1m 47s	remaining: 3.02s
# 4864:	learn: 0.0000002	total: 1m 47s	remaining: 3s
# 4865:	learn: 0.0000002	total: 1m 48s	remaining: 2.97s
# 4866:	learn: 0.0000002	total: 1m 48s	remaining: 2.95s
# 4867:	learn: 0.0000002	total: 1m 48s	remaining: 2.93s
# 4868:	learn: 0.0000002	total: 1m 48s	remaining: 2.91s
# 4869:	learn: 0.0000002	total: 1m 48s	remaining: 2.89s
# 4870:	learn: 0.0000002	total: 1m 48s	remaining: 2.87s
# 4871:	learn: 0.0000002	total: 1m 48s	remaining: 2.84s
# 4872:	learn: 0.0000002	total: 1m 48s	remaining: 2.82s
# 4873:	learn: 0.0000002	total: 1m 48s	remaining: 2.8s
# 4874:	learn: 0.0000002	total: 1m 48s	remaining: 2.78s
# 4875:	learn: 0.0000002	total: 1m 48s	remaining: 2.76s
# 4876:	learn: 0.0000002	total: 1m 48s	remaining: 2.73s
# 4877:	learn: 0.0000002	total: 1m 48s	remaining: 2.71s
# 4878:	learn: 0.0000002	total: 1m 48s	remaining: 2.69s
# 4879:	learn: 0.0000002	total: 1m 48s	remaining: 2.67s
# 4880:	learn: 0.0000002	total: 1m 48s	remaining: 2.65s
# 4881:	learn: 0.0000002	total: 1m 48s	remaining: 2.63s
# 4882:	learn: 0.0000002	total: 1m 48s	remaining: 2.6s
# 4883:	learn: 0.0000002	total: 1m 48s	remaining: 2.58s
# 4884:	learn: 0.0000002	total: 1m 48s	remaining: 2.56s
# 4885:	learn: 0.0000002	total: 1m 48s	remaining: 2.54s
# 4886:	learn: 0.0000002	total: 1m 48s	remaining: 2.52s
# 4887:	learn: 0.0000002	total: 1m 48s	remaining: 2.49s
# 4888:	learn: 0.0000002	total: 1m 48s	remaining: 2.47s
# 4889:	learn: 0.0000002	total: 1m 48s	remaining: 2.45s
# 4890:	learn: 0.0000002	total: 1m 48s	remaining: 2.43s
# 4891:	learn: 0.0000002	total: 1m 48s	remaining: 2.4s
# 4892:	learn: 0.0000002	total: 1m 49s	remaining: 2.38s
# 4893:	learn: 0.0000002	total: 1m 49s	remaining: 2.36s
# 4894:	learn: 0.0000002	total: 1m 49s	remaining: 2.34s
# 4895:	learn: 0.0000002	total: 1m 49s	remaining: 2.32s
# 4896:	learn: 0.0000002	total: 1m 49s	remaining: 2.3s
# 4897:	learn: 0.0000002	total: 1m 49s	remaining: 2.27s
# 4898:	learn: 0.0000002	total: 1m 49s	remaining: 2.25s
# 4899:	learn: 0.0000002	total: 1m 49s	remaining: 2.23s
# 4900:	learn: 0.0000002	total: 1m 49s	remaining: 2.21s
# 4901:	learn: 0.0000002	total: 1m 49s	remaining: 2.19s
# 4902:	learn: 0.0000002	total: 1m 49s	remaining: 2.16s
# 4903:	learn: 0.0000002	total: 1m 49s	remaining: 2.14s
# 4904:	learn: 0.0000002	total: 1m 49s	remaining: 2.12s
# 4905:	learn: 0.0000002	total: 1m 49s	remaining: 2.1s
# 4906:	learn: 0.0000002	total: 1m 49s	remaining: 2.08s
# 4907:	learn: 0.0000002	total: 1m 49s	remaining: 2.05s
# 4908:	learn: 0.0000002	total: 1m 49s	remaining: 2.03s
# 4909:	learn: 0.0000002	total: 1m 49s	remaining: 2.01s
# 4910:	learn: 0.0000002	total: 1m 49s	remaining: 1.99s
# 4911:	learn: 0.0000002	total: 1m 49s	remaining: 1.97s
# 4912:	learn: 0.0000002	total: 1m 49s	remaining: 1.94s
# 4913:	learn: 0.0000002	total: 1m 49s	remaining: 1.92s
# 4914:	learn: 0.0000002	total: 1m 49s	remaining: 1.9s
# 4915:	learn: 0.0000002	total: 1m 49s	remaining: 1.88s
# 4916:	learn: 0.0000002	total: 1m 49s	remaining: 1.85s
# 4917:	learn: 0.0000002	total: 1m 49s	remaining: 1.83s
# 4918:	learn: 0.0000002	total: 1m 49s	remaining: 1.81s
# 4919:	learn: 0.0000002	total: 1m 50s	remaining: 1.79s
# 4920:	learn: 0.0000002	total: 1m 50s	remaining: 1.77s
# 4921:	learn: 0.0000002	total: 1m 50s	remaining: 1.74s
# 4922:	learn: 0.0000002	total: 1m 50s	remaining: 1.72s
# 4923:	learn: 0.0000002	total: 1m 50s	remaining: 1.7s
# 4924:	learn: 0.0000002	total: 1m 50s	remaining: 1.68s
# 4925:	learn: 0.0000002	total: 1m 50s	remaining: 1.66s
# 4926:	learn: 0.0000002	total: 1m 50s	remaining: 1.63s
# 4927:	learn: 0.0000002	total: 1m 50s	remaining: 1.61s
# 4928:	learn: 0.0000002	total: 1m 50s	remaining: 1.59s
# 4929:	learn: 0.0000002	total: 1m 50s	remaining: 1.57s
# 4930:	learn: 0.0000002	total: 1m 50s	remaining: 1.54s
# 4931:	learn: 0.0000002	total: 1m 50s	remaining: 1.52s
# 4932:	learn: 0.0000002	total: 1m 50s	remaining: 1.5s
# 4933:	learn: 0.0000002	total: 1m 50s	remaining: 1.48s
# 4934:	learn: 0.0000002	total: 1m 50s	remaining: 1.46s
# 4935:	learn: 0.0000002	total: 1m 50s	remaining: 1.43s
# 4936:	learn: 0.0000002	total: 1m 50s	remaining: 1.41s
# 4937:	learn: 0.0000001	total: 1m 50s	remaining: 1.39s
# 4938:	learn: 0.0000001	total: 1m 50s	remaining: 1.37s
# 4939:	learn: 0.0000001	total: 1m 50s	remaining: 1.34s
# 4940:	learn: 0.0000001	total: 1m 50s	remaining: 1.32s
# 4941:	learn: 0.0000001	total: 1m 50s	remaining: 1.3s
# 4942:	learn: 0.0000001	total: 1m 50s	remaining: 1.28s
# 4943:	learn: 0.0000001	total: 1m 50s	remaining: 1.25s
# 4944:	learn: 0.0000001	total: 1m 50s	remaining: 1.23s
# 4945:	learn: 0.0000001	total: 1m 50s	remaining: 1.21s
# 4946:	learn: 0.0000001	total: 1m 50s	remaining: 1.19s
# 4947:	learn: 0.0000001	total: 1m 50s	remaining: 1.17s
# 4948:	learn: 0.0000001	total: 1m 50s	remaining: 1.14s
# 4949:	learn: 0.0000001	total: 1m 50s	remaining: 1.12s
# 4950:	learn: 0.0000001	total: 1m 50s	remaining: 1.1s
# 4951:	learn: 0.0000001	total: 1m 50s	remaining: 1.07s
# 4952:	learn: 0.0000001	total: 1m 50s	remaining: 1.05s
# 4953:	learn: 0.0000001	total: 1m 50s	remaining: 1.03s
# 4954:	learn: 0.0000001	total: 1m 50s	remaining: 1.01s
# 4955:	learn: 0.0000001	total: 1m 51s	remaining: 986ms
# 4956:	learn: 0.0000001	total: 1m 51s	remaining: 963ms
# 4957:	learn: 0.0000001	total: 1m 51s	remaining: 941ms
# 4958:	learn: 0.0000001	total: 1m 51s	remaining: 918ms
# 4959:	learn: 0.0000001	total: 1m 51s	remaining: 896ms
# 4960:	learn: 0.0000001	total: 1m 51s	remaining: 873ms
# 4961:	learn: 0.0000001	total: 1m 51s	remaining: 851ms
# 4962:	learn: 0.0000001	total: 1m 51s	remaining: 829ms
# 4963:	learn: 0.0000001	total: 1m 51s	remaining: 806ms
# 4964:	learn: 0.0000001	total: 1m 51s	remaining: 784ms
# 4965:	learn: 0.0000001	total: 1m 51s	remaining: 761ms
# 4966:	learn: 0.0000001	total: 1m 51s	remaining: 739ms
# 4967:	learn: 0.0000001	total: 1m 51s	remaining: 716ms
# 4968:	learn: 0.0000001	total: 1m 51s	remaining: 694ms
# 4969:	learn: 0.0000001	total: 1m 51s	remaining: 672ms
# 4970:	learn: 0.0000001	total: 1m 51s	remaining: 649ms
# 4971:	learn: 0.0000001	total: 1m 51s	remaining: 627ms
# 4972:	learn: 0.0000001	total: 1m 51s	remaining: 604ms
# 4973:	learn: 0.0000001	total: 1m 51s	remaining: 582ms
# 4974:	learn: 0.0000001	total: 1m 51s	remaining: 560ms
# 4975:	learn: 0.0000001	total: 1m 51s	remaining: 537ms
# 4976:	learn: 0.0000001	total: 1m 51s	remaining: 515ms
# 4977:	learn: 0.0000001	total: 1m 51s	remaining: 492ms
# 4978:	learn: 0.0000001	total: 1m 51s	remaining: 470ms
# 4979:	learn: 0.0000001	total: 1m 51s	remaining: 448ms
# 4980:	learn: 0.0000001	total: 1m 51s	remaining: 425ms
# 4981:	learn: 0.0000001	total: 1m 51s	remaining: 403ms
# 4982:	learn: 0.0000001	total: 1m 51s	remaining: 380ms
# 4983:	learn: 0.0000001	total: 1m 51s	remaining: 358ms
# 4984:	learn: 0.0000001	total: 1m 51s	remaining: 336ms
# 4985:	learn: 0.0000001	total: 1m 51s	remaining: 313ms
# 4986:	learn: 0.0000001	total: 1m 51s	remaining: 291ms
# 4987:	learn: 0.0000001	total: 1m 51s	remaining: 268ms
# 4988:	learn: 0.0000001	total: 1m 51s	remaining: 246ms
# 4989:	learn: 0.0000001	total: 1m 51s	remaining: 224ms
# 4990:	learn: 0.0000001	total: 1m 51s	remaining: 201ms
# 4991:	learn: 0.0000001	total: 1m 51s	remaining: 179ms
# 4992:	learn: 0.0000001	total: 1m 51s	remaining: 157ms
# 4993:	learn: 0.0000001	total: 1m 51s	remaining: 134ms
# 4994:	learn: 0.0000001	total: 1m 51s	remaining: 112ms
# 4995:	learn: 0.0000001	total: 1m 51s	remaining: 89.5ms
# 4996:	learn: 0.0000001	total: 1m 51s	remaining: 67.1ms
# 4997:	learn: 0.0000001	total: 1m 51s	remaining: 44.7ms
# 4998:	learn: 0.0000001	total: 1m 51s	remaining: 22.4ms
# 4999:	learn: 0.0000001	total: 1m 51s	remaining: 0us
# {'depth': 9, 'iterations': 5000, 'learning_rate': 0.04013590769201548}

# %%
best_cat = grid.best_estimator_
grid.best_params_
# Out:
# {'depth': 9, 'iterations': 5000, 'learning_rate': 0.04013590769201548}

# %%
grid.best_score_
# Out:
# -3.754187690316621

# %%
best_cat.save_model('parsed_ratings_okko_tune_ntop_scrs_kws_views_russ')

# %%
y_pred = best_cat.predict(test_dataset)

# %%
target_distr_linear(y_train, y_test, y_pred)

# %%
calc_metrics(inverse_transform(y_test), inverse_transform(y_pred))
# Out:
# *** VAL **:
# MSE:   0.0001830759753263503
# RMSE:  0.013530557095934754
# R2:    -2.5006167737932112
# MAE:   0.011429115607869423
# MedAE: 0.012004590582296954
# ------------------------------

# %%
get_feature_imp(best_cat, train_dataset)

# %%
test_df['PREDS_tune'] = y_pred.tolist()
test_df
# Out:
#     age_access_type                    name   type  release_year   duration  \
# 710              18                    Ника  MOVIE          2022  15.566448
# 396              18               Приплыли!  MOVIE          2022  15.479437
# 158              16             Многоэтажка  MOVIE          2022  15.597220
# 747              12           Тайна амулета  MOVIE          2022  15.545395
# 203              16  День слепого Валентина  MOVIE          2022  15.711630
# 332              16          Доктор Свисток  MOVIE          2022  15.332833
# 711              12            Первый Оскар  MOVIE          2022  15.738298
#
#                               element_uid  BUDGET  MARKETING        RUS  USA  \
# 710  5bd9b8c0-b482-4953-951a-813985e55e2d     NaN        NaN  12.233522  NaN
# 396  02eaefe0-296d-4e6f-b52f-2e2507d07103     NaN        NaN  12.593543  NaN
# 158  19a61cc3-65ff-46ce-bf43-29c24a1cc9b6     NaN        NaN   5.793014  NaN
# 747  9ae35927-93e3-4a40-870f-a998abbeaa9f     NaN        NaN  12.057422  NaN
# 203  6b047b99-5cb4-4878-9a4f-b8b372b438eb     NaN        NaN  12.935033  NaN
# 332  967bf940-27b7-4d93-95ad-43c7459077e7     NaN        NaN  12.638501  NaN
# 711  e69d2f4d-bb65-4e7e-93e1-74da99424ae8     NaN        NaN  14.252288  NaN
#
#      ...  Сергей Трофимов  Максим Осадчий  Сергей Сельянов  Георгий Малков  \
# 710  ...                0               0                0               0
# 396  ...                0               0                0               0
# 158  ...                0               0                0               0
# 747  ...                0               0                0               0
# 203  ...                0               0                0               0
# 332  ...                0               0                0               1
# 711  ...                0               0                0               0
#
#      Тимур Бекмамбетов  Роман Непомнящий  Александр Боярский     PREDS  \
# 710                  0                 0                   0  0.000095
# 396                  0                 0                   0  0.000698
# 158                  0                 0                   0  0.000127
# 747                  0                 0                   0  0.000139
# 203                  0                 0                   0  0.000083
# 332                  0                 0                   0  0.000070
# 711                  0                 0                   0  0.000470
#
#        TARGET  PREDS_tune
# 710  0.004464    0.000096
# 396  0.009902    0.000661
# 158  0.017114    0.000101
# 747  0.000178    0.000054
# 203  0.023361    0.000052
# 332  0.012031    0.000099
# 711  0.013736    0.000369
#
# [7 rows x 1056 columns]
