# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from collections import Counter

import statsmodels.stats.api as sms
from matplotlib import style
style.use('seaborn')
# %matplotlib inline
#graphs in svg look clearer
# %config InlineBackend.figure_format = 'svg'

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Unhashing

# %%
genre_mapping = {'0ef0aa70-f86c-4141-8054-8b39af97867d': 'Biography',
                '287a1485-7a88-4c2f-bc94-ca418b6c47a1': 'Cartoons',
                '66fad8c3-d84f-458d-a8bf-5b4f154969e0': 'Show',
                '7b7c97f6-1adb-4b43-bfe8-9455812fac0b': 'Theater',
                '9fa28b61-a257-4a3e-945b-a9ef76a146d6': 'Fantasy',
                'b0836a1d-635f-4d89-bcc5-25d10ba56642': 'Anime',
                'd7214feb-8c11-4aea-aabb-ac98a8d56fd5': 'History',
                'dc65dbc8-34ba-4df1-b32c-4f895e10bff8': 'Shorts',
                'eb001d27-5be3-4d42-9d88-90d593f2627d': 'War_movies',
                '364fdc2e-bdfe-40be-b2c5-d30f43ec432e': 'Crime',
                '1f22ccf1-288a-4e6e-b39a-7502799e7125': 'Лекции',
                '6d640e04-be3a-4c8c-852e-4e9b12449d5d': 'Концерты',
                '7b7c97f6-1adb-4b43-bfe8-9455812fac0b': 'Театр',
                '2f7908cc-e2fd-43cf-b626-ec1aef436160': 'Курсы'}

# %%
import pickle

with open('./NEW_OKKO_KINOP_parsed_ratings_df.pkl', 'rb') as f:
    df = pickle.load(f, encoding='utf-8')

# %%
df.shape
# Out:
# (10731, 27)

# %%
df.isna().sum()
# Out:
# age_access_type        0
# name                   0
# director               3
# genre                  0
# average_rating       459
# type                   0
# country                0
# release_type           0
# release_year           0
# duration               0
# actor                  0
# element_uid            0
# ACTOR                211
# COMPOSER            1390
# DESIGN              1488
# DIRECTOR             152
# EDITOR              1896
# OPERATOR            1479
# PRODUCER            1193
# WRITER               339
# BUDGET              7432
# MARKETING          10478
# RUS                 7101
# USA                 7082
# WORLD               5434
# element_id             0
# rating                 0
# dtype: int64

# %%
all_genres = []

for item_genres in df['genre']:
    all_genres.extend(item_genres)

# %%
all_unique_genres = set(all_genres)

# %%
len(all_unique_genres)
# Out:
# 33

# %%
all_unique_genres
# Out:
# {'0ef0aa70-f86c-4141-8054-8b39af97867d',
#  '1f22ccf1-288a-4e6e-b39a-7502799e7125',
#  '287a1485-7a88-4c2f-bc94-ca418b6c47a1',
#  '364fdc2e-bdfe-40be-b2c5-d30f43ec432e',
#  '3e6e08b4-2bb0-46d6-aee7-98780e394c86',
#  '5743ecbe-a141-47d6-a7d7-e800f41cb6f5',
#  '5c403894-146a-47a4-ae75-9f1956a30dbb',
#  '66fad8c3-d84f-458d-a8bf-5b4f154969e0',
#  '6d640e04-be3a-4c8c-852e-4e9b12449d5d',
#  '7b7c97f6-1adb-4b43-bfe8-9455812fac0b',
#  '9fa28b61-a257-4a3e-945b-a9ef76a146d6',
#  'Action',
#  'Adventure',
#  'ArtHouse',
#  'Comedy',
#  'Detective',
#  'Documentary',
#  'Drama',
#  'Family',
#  'ForKids',
#  'Horror',
#  'Humor',
#  'Melodrama',
#  'Music',
#  'Sci-Fi',
#  'Sport',
#  'Thriller',
#  'Travel',
#  'b0836a1d-635f-4d89-bcc5-25d10ba56642',
#  'd7214feb-8c11-4aea-aabb-ac98a8d56fd5',
#  'd7f6b51c-6ebe-4b9c-9aad-2c60792a7d9c',
#  'dc65dbc8-34ba-4df1-b32c-4f895e10bff8',
#  'eb001d27-5be3-4d42-9d88-90d593f2627d'}

# %%
decoded_genres = [genre_mapping.get(genre, genre) for genre in all_unique_genres]

# %%
decoded_genres
# Out:
# ['Humor',
#  'Melodrama',
#  'Концерты',
#  'Thriller',
#  'Sci-Fi',
#  'Biography',
#  'd7f6b51c-6ebe-4b9c-9aad-2c60792a7d9c',
#  'Cartoons',
#  'Detective',
#  '3e6e08b4-2bb0-46d6-aee7-98780e394c86',
#  'Documentary',
#  '5743ecbe-a141-47d6-a7d7-e800f41cb6f5',
#  'Adventure',
#  'Horror',
#  '5c403894-146a-47a4-ae75-9f1956a30dbb',
#  'Music',
#  'Anime',
#  'Лекции',
#  'Action',
#  'Show',
#  'War_movies',
#  'Shorts',
#  'History',
#  'ForKids',
#  'Comedy',
#  'Family',
#  'ArtHouse',
#  'Театр',
#  'Sport',
#  'Drama',
#  'Travel',
#  'Crime',
#  'Fantasy']

# %% [markdown]
# # Preprocessing

# %%
df.head().T
# Out:
#                                                                  0  \
# age_access_type                                                 12
# name                              Звёздный путь 5: Последний рубеж
# director                    [cff3362f-ad91-498d-80b3-ea3ab8ec65cf]
# genre                        [Sci-Fi, Action, Thriller, Adventure]
# average_rating                                                6.21
# type                                                         MOVIE
# country                                                      [usa]
# release_type                                               RELEASE
# release_year                                                  1989
# duration                                                 6420000.0
# actor            [cff3362f-ad91-498d-80b3-ea3ab8ec65cf, 21c7a45...
# element_uid                   e785baa6-f175-42b4-9e16-4319ac7991d5
# ACTOR            [Уильям Шетнер, Леонард Нимой, ДеФорест Келли,...
# COMPOSER                               [Джерри Голдсмит, Хиросима]
# DESIGN           [Херман Ф. Зиммерман, Нило Родис-Джамеро, Джон...
# DIRECTOR                                           [Уильям Шетнер]
# EDITOR                                           [Питер Е. Бергер]
# OPERATOR                                             [Эндрю Ласло]
# PRODUCER         [Харви Беннетт, Брук Бретон, Мэл Эфрос, Джин Р...
# WRITER           [Джин Родденберри, Уильям Шетнер, Харви Беннет...
# BUDGET                                                  27800000.0
# MARKETING                                                      NaN
# RUS                                                            NaN
# USA                                                     52210049.0
# WORLD                                                   52210049.0
# element_id                    e785baa6-f175-42b4-9e16-4319ac7991d5
# rating                                                    8.339286
#
#                                                                  1  \
# age_access_type                                                 16
# name                            Звёздный путь 6: Неоткрытая страна
# director                    [bab6b7f4-4506-458f-9091-d567505674f2]
# genre                        [Sci-Fi, Action, Thriller, Adventure]
# average_rating                                                 7.2
# type                                                         MOVIE
# country                                                      [usa]
# release_type                                               RELEASE
# release_year                                                  1991
# duration                                                 6780000.0
# actor            [cff3362f-ad91-498d-80b3-ea3ab8ec65cf, 21c7a45...
# element_uid                   4593737e-de9c-40df-97db-fb3cf85a08ef
# ACTOR            [Уильям Шетнер, Леонард Нимой, ДеФорест Келли,...
# COMPOSER                                         [Клифф Эйдельман]
# DESIGN           [Херман Ф. Зиммерман, Нило Родис-Джамеро, Доди...
# DIRECTOR                                           [Николас Мейер]
# EDITOR                                   [Уильям Хой, Рональд Руз]
# OPERATOR                                             [Хиро Нарита]
# PRODUCER         [Стивен-Чарльз Джаффе, Ральф Уинтер, Брук Брет...
# WRITER           [Джин Родденберри, Леонард Нимой, Лоуренс Конн...
# BUDGET                                                  30000000.0
# MARKETING                                                      NaN
# RUS                                                            NaN
# USA                                                     74888996.0
# WORLD                                                   96888996.0
# element_id                    4593737e-de9c-40df-97db-fb3cf85a08ef
# rating                                                    8.785714
#
#                                                                  2  \
# age_access_type                                                 18
# name                                  В поисках древнего артефакта
# director                    [895f5774-964a-4c5a-ae22-d697d3e3e620]
# genre                                                     [Horror]
# average_rating                                                 4.0
# type                                                         MOVIE
# country                                                      [usa]
# release_type                                               RELEASE
# release_year                                                  2019
# duration                                                 6000000.0
# actor            [cff3362f-ad91-498d-80b3-ea3ab8ec65cf, bcad17e...
# element_uid                   11ba66db-e941-4c3a-8da6-d8900e56f8c7
# ACTOR            [Уильям Шетнер, Джери Райан, Джейсон Брукс, Ро...
# COMPOSER                                                       NaN
# DESIGN                    [Линдсей Моремен, Нина Чермак Розенберг]
# DIRECTOR                                              [Джаред Кон]
# EDITOR                                                         NaN
# OPERATOR                                                       NaN
# PRODUCER              [Джаред Кон, Майкл Мейландер, Брайан Перера]
# WRITER                                               [Морис Хёрли]
# BUDGET                                                         NaN
# MARKETING                                                      NaN
# RUS                                                            NaN
# USA                                                            NaN
# WORLD                                                          NaN
# element_id                    11ba66db-e941-4c3a-8da6-d8900e56f8c7
# rating                                                    3.115385
#
#                                                                  3  \
# age_access_type                                                 18
# name                                           Прожарка Чарли Шина
# director                    [1de22aff-430e-4af9-bf1d-159dbf8e9269]
# genre                                        [Comedy, Documentary]
# average_rating                                                6.99
# type                                                         MOVIE
# country                                                      [usa]
# release_type                                               RELEASE
# release_year                                                  2011
# duration                                                 3780000.0
# actor            [cff3362f-ad91-498d-80b3-ea3ab8ec65cf, 30dd19c...
# element_uid                   3f30a2ef-53b7-40e3-954f-1bdfc38a6d17
# ACTOR            [Чарли Шин, Сет МакФарлейн, Майк Тайсон, Кейт ...
# COMPOSER                                                       NaN
# DESIGN                              [Джон Кэлкинс, Ричард Шрайбер]
# DIRECTOR                                            [Джоэл Галлен]
# EDITOR                                                         NaN
# OPERATOR                                                       NaN
# PRODUCER         [Рик Остин, Марк Бёрг, Роб Кроуфорд, Джоэл Гал...
# WRITER           [Рэй Джеймс, Майкл Ферруччи, Крис МакГуайр, Фр...
# BUDGET                                                         NaN
# MARKETING                                                      NaN
# RUS                                                            NaN
# USA                                                            NaN
# WORLD                                                          NaN
# element_id                    3f30a2ef-53b7-40e3-954f-1bdfc38a6d17
# rating                                                    7.513889
#
#                                                                  4
# age_access_type                                                 18
# name                                      Прожарка Уильяма Шэтнера
# director                    [1de22aff-430e-4af9-bf1d-159dbf8e9269]
# genre                                                     [Comedy]
# average_rating                                                 6.0
# type                                                         MOVIE
# country                                                      [usa]
# release_type                                               RELEASE
# release_year                                                  2006
# duration                                                 3780000.0
# actor            [cff3362f-ad91-498d-80b3-ea3ab8ec65cf, a805fdd...
# element_uid                   cdfa700f-122d-41e5-b8dc-9c6813bab6d2
# ACTOR            [Уильям Шетнер, Джейсон Александер, Фарра Фосе...
# COMPOSER                                                       NaN
# DESIGN                                 [Джон Кэлкинс, Паула Элинс]
# DIRECTOR                                            [Джоэл Галлен]
# EDITOR                              [Билл ДеРонде, Наруми Инацугу]
# OPERATOR                                                       NaN
# PRODUCER         [Рик Остин, Роб Кроуфорд, Джоэл Галлен, Мишель...
# WRITER           [Майкл Ферруччи, Мэтью Харауиц, Джо Келли, Аар...
# BUDGET                                                         NaN
# MARKETING                                                      NaN
# RUS                                                            NaN
# USA                                                            NaN
# WORLD                                                          NaN
# element_id                    cdfa700f-122d-41e5-b8dc-9c6813bab6d2
# rating                                                    6.583333

# %%
df.shape
# Out:
# (10731, 27)

# %%
df.head().T
# Out:
#                                                                  0  \
# age_access_type                                                 12
# name                              Звёздный путь 5: Последний рубеж
# director                    [cff3362f-ad91-498d-80b3-ea3ab8ec65cf]
# genre                        [Sci-Fi, Action, Thriller, Adventure]
# average_rating                                                6.21
# type                                                         MOVIE
# country                                                      [usa]
# release_type                                               RELEASE
# release_year                                                  1989
# duration                                                 6420000.0
# actor            [cff3362f-ad91-498d-80b3-ea3ab8ec65cf, 21c7a45...
# element_uid                   e785baa6-f175-42b4-9e16-4319ac7991d5
# ACTOR            [Уильям Шетнер, Леонард Нимой, ДеФорест Келли,...
# COMPOSER                               [Джерри Голдсмит, Хиросима]
# DESIGN           [Херман Ф. Зиммерман, Нило Родис-Джамеро, Джон...
# DIRECTOR                                           [Уильям Шетнер]
# EDITOR                                           [Питер Е. Бергер]
# OPERATOR                                             [Эндрю Ласло]
# PRODUCER         [Харви Беннетт, Брук Бретон, Мэл Эфрос, Джин Р...
# WRITER           [Джин Родденберри, Уильям Шетнер, Харви Беннет...
# BUDGET                                                  27800000.0
# MARKETING                                                      NaN
# RUS                                                            NaN
# USA                                                     52210049.0
# WORLD                                                   52210049.0
# element_id                    e785baa6-f175-42b4-9e16-4319ac7991d5
# rating                                                    8.339286
#
#                                                                  1  \
# age_access_type                                                 16
# name                            Звёздный путь 6: Неоткрытая страна
# director                    [bab6b7f4-4506-458f-9091-d567505674f2]
# genre                        [Sci-Fi, Action, Thriller, Adventure]
# average_rating                                                 7.2
# type                                                         MOVIE
# country                                                      [usa]
# release_type                                               RELEASE
# release_year                                                  1991
# duration                                                 6780000.0
# actor            [cff3362f-ad91-498d-80b3-ea3ab8ec65cf, 21c7a45...
# element_uid                   4593737e-de9c-40df-97db-fb3cf85a08ef
# ACTOR            [Уильям Шетнер, Леонард Нимой, ДеФорест Келли,...
# COMPOSER                                         [Клифф Эйдельман]
# DESIGN           [Херман Ф. Зиммерман, Нило Родис-Джамеро, Доди...
# DIRECTOR                                           [Николас Мейер]
# EDITOR                                   [Уильям Хой, Рональд Руз]
# OPERATOR                                             [Хиро Нарита]
# PRODUCER         [Стивен-Чарльз Джаффе, Ральф Уинтер, Брук Брет...
# WRITER           [Джин Родденберри, Леонард Нимой, Лоуренс Конн...
# BUDGET                                                  30000000.0
# MARKETING                                                      NaN
# RUS                                                            NaN
# USA                                                     74888996.0
# WORLD                                                   96888996.0
# element_id                    4593737e-de9c-40df-97db-fb3cf85a08ef
# rating                                                    8.785714
#
#                                                                  2  \
# age_access_type                                                 18
# name                                  В поисках древнего артефакта
# director                    [895f5774-964a-4c5a-ae22-d697d3e3e620]
# genre                                                     [Horror]
# average_rating                                                 4.0
# type                                                         MOVIE
# country                                                      [usa]
# release_type                                               RELEASE
# release_year                                                  2019
# duration                                                 6000000.0
# actor            [cff3362f-ad91-498d-80b3-ea3ab8ec65cf, bcad17e...
# element_uid                   11ba66db-e941-4c3a-8da6-d8900e56f8c7
# ACTOR            [Уильям Шетнер, Джери Райан, Джейсон Брукс, Ро...
# COMPOSER                                                       NaN
# DESIGN                    [Линдсей Моремен, Нина Чермак Розенберг]
# DIRECTOR                                              [Джаред Кон]
# EDITOR                                                         NaN
# OPERATOR                                                       NaN
# PRODUCER              [Джаред Кон, Майкл Мейландер, Брайан Перера]
# WRITER                                               [Морис Хёрли]
# BUDGET                                                         NaN
# MARKETING                                                      NaN
# RUS                                                            NaN
# USA                                                            NaN
# WORLD                                                          NaN
# element_id                    11ba66db-e941-4c3a-8da6-d8900e56f8c7
# rating                                                    3.115385
#
#                                                                  3  \
# age_access_type                                                 18
# name                                           Прожарка Чарли Шина
# director                    [1de22aff-430e-4af9-bf1d-159dbf8e9269]
# genre                                        [Comedy, Documentary]
# average_rating                                                6.99
# type                                                         MOVIE
# country                                                      [usa]
# release_type                                               RELEASE
# release_year                                                  2011
# duration                                                 3780000.0
# actor            [cff3362f-ad91-498d-80b3-ea3ab8ec65cf, 30dd19c...
# element_uid                   3f30a2ef-53b7-40e3-954f-1bdfc38a6d17
# ACTOR            [Чарли Шин, Сет МакФарлейн, Майк Тайсон, Кейт ...
# COMPOSER                                                       NaN
# DESIGN                              [Джон Кэлкинс, Ричард Шрайбер]
# DIRECTOR                                            [Джоэл Галлен]
# EDITOR                                                         NaN
# OPERATOR                                                       NaN
# PRODUCER         [Рик Остин, Марк Бёрг, Роб Кроуфорд, Джоэл Гал...
# WRITER           [Рэй Джеймс, Майкл Ферруччи, Крис МакГуайр, Фр...
# BUDGET                                                         NaN
# MARKETING                                                      NaN
# RUS                                                            NaN
# USA                                                            NaN
# WORLD                                                          NaN
# element_id                    3f30a2ef-53b7-40e3-954f-1bdfc38a6d17
# rating                                                    7.513889
#
#                                                                  4
# age_access_type                                                 18
# name                                      Прожарка Уильяма Шэтнера
# director                    [1de22aff-430e-4af9-bf1d-159dbf8e9269]
# genre                                                     [Comedy]
# average_rating                                                 6.0
# type                                                         MOVIE
# country                                                      [usa]
# release_type                                               RELEASE
# release_year                                                  2006
# duration                                                 3780000.0
# actor            [cff3362f-ad91-498d-80b3-ea3ab8ec65cf, a805fdd...
# element_uid                   cdfa700f-122d-41e5-b8dc-9c6813bab6d2
# ACTOR            [Уильям Шетнер, Джейсон Александер, Фарра Фосе...
# COMPOSER                                                       NaN
# DESIGN                                 [Джон Кэлкинс, Паула Элинс]
# DIRECTOR                                            [Джоэл Галлен]
# EDITOR                              [Билл ДеРонде, Наруми Инацугу]
# OPERATOR                                                       NaN
# PRODUCER         [Рик Остин, Роб Кроуфорд, Джоэл Галлен, Мишель...
# WRITER           [Майкл Ферруччи, Мэтью Харауиц, Джо Келли, Аар...
# BUDGET                                                         NaN
# MARKETING                                                      NaN
# RUS                                                            NaN
# USA                                                            NaN
# WORLD                                                          NaN
# element_id                    cdfa700f-122d-41e5-b8dc-9c6813bab6d2
# rating                                                    6.583333

# %% [markdown]
# ## Add keywords

# %%
kwds = pd.read_csv('keywords_df_for_each_content.csv', index_col=0)

# %%
kwds.head().T
# Out:
#                            e785baa6-f175-42b4-9e16-4319ac7991d5  \
# джек                                                          0
# расследовать                                                  0
# подруга                                                       0
# ограбление                                                    0
# катя                                                          0
# ...                                                         ...
# таможенный                                                    0
# диабет                                                        0
# млрд                                                          0
# рф                                                            0
# texts         ['кризис', 'разражаться', 'песчаный', 'планета...
#
#                            4593737e-de9c-40df-97db-fb3cf85a08ef  \
# джек                                                          0
# расследовать                                                  0
# подруга                                                       0
# ограбление                                                    0
# катя                                                          0
# ...                                                         ...
# таможенный                                                    0
# диабет                                                        0
# млрд                                                          0
# рф                                                            0
# texts         ['взрыв', 'праксис', 'луна', 'кронос', 'уничто...
#
#                            11ba66db-e941-4c3a-8da6-d8900e56f8c7  \
# джек                                                          0
# расследовать                                                  0
# подруга                                                       0
# ограбление                                                    0
# катя                                                          0
# ...                                                         ...
# таможенный                                                    0
# диабет                                                        0
# млрд                                                          0
# рф                                                            0
# texts         ['неудачливый', 'археолог', 'возвращаться', 'э...
#
#                            3f30a2ef-53b7-40e3-954f-1bdfc38a6d17  \
# джек                                                          0
# расследовать                                                  0
# подруга                                                       0
# ограбление                                                    0
# катя                                                          0
# ...                                                         ...
# таможенный                                                    0
# диабет                                                        0
# млрд                                                          0
# рф                                                            0
# texts         ['поджарка', 'записывать', 'лосанджелес', 'сен...
#
#                            ba6bec1a-3aa9-48c7-aa65-908c21627a12
# джек                                                          0
# расследовать                                                  0
# подруга                                                       0
# ограбление                                                    0
# катя                                                          0
# ...                                                         ...
# таможенный                                                    0
# диабет                                                        0
# млрд                                                          0
# рф                                                            0
# texts         ['самый', 'детство', 'джорджия', 'нолан', 'меч...
#
# [33833 rows x 5 columns]

# %%
kwds_df = kwds.drop('texts', axis=1).reset_index().rename(columns={'index':'element_id'})

# %%
kwds_df.head().T
# Out:
#                                                  0  \
# element_id    e785baa6-f175-42b4-9e16-4319ac7991d5
# джек                                             0
# расследовать                                     0
# подруга                                          0
# ограбление                                       0
# ...                                            ...
# собственник                                      0
# таможенный                                       0
# диабет                                           0
# млрд                                             0
# рф                                               0
#
#                                                  1  \
# element_id    4593737e-de9c-40df-97db-fb3cf85a08ef
# джек                                             0
# расследовать                                     0
# подруга                                          0
# ограбление                                       0
# ...                                            ...
# собственник                                      0
# таможенный                                       0
# диабет                                           0
# млрд                                             0
# рф                                               0
#
#                                                  2  \
# element_id    11ba66db-e941-4c3a-8da6-d8900e56f8c7
# джек                                             0
# расследовать                                     0
# подруга                                          0
# ограбление                                       0
# ...                                            ...
# собственник                                      0
# таможенный                                       0
# диабет                                           0
# млрд                                             0
# рф                                               0
#
#                                                  3  \
# element_id    3f30a2ef-53b7-40e3-954f-1bdfc38a6d17
# джек                                             0
# расследовать                                     0
# подруга                                          0
# ограбление                                       0
# ...                                            ...
# собственник                                      0
# таможенный                                       0
# диабет                                           0
# млрд                                             0
# рф                                               0
#
#                                                  4
# element_id    ba6bec1a-3aa9-48c7-aa65-908c21627a12
# джек                                             0
# расследовать                                     0
# подруга                                          0
# ограбление                                       0
# ...                                            ...
# собственник                                      0
# таможенный                                       0
# диабет                                           0
# млрд                                             0
# рф                                               0
#
# [33833 rows x 5 columns]

# %%
df_merged = df.merge(kwds_df, on='element_id', how='inner')

# %%
df_merged.shape
# Out:
# (10489, 33859)

# %%
with open('Okko_ratings_all_content_FULL_kws.pkl', 'wb') as f:
    pickle.dump(df_merged, f)

# %%
################

# %%
def  get_certain_country(data: pd.DataFrame, country_name: str):
    df = data.copy(deep=True)
    for idx, row in df.iterrows():
        countries = row['country']
        country_presence = False
        for country in countries:
            if country == country_name:
                country_presence = True
        if not country_presence:
            df.drop(labels=idx, axis=0, inplace=True)
    
    return df

# %% [markdown]
# ## Get russian content

# %%
russ_content = get_certain_country(df_merged, 'russia')

# %%
russ_content.head().T
# Out:
#                                                     143  \
# age_access_type                                      16
# name                                               Айка
# director         [8fa71c53-ca22-44f0-bd9f-af273eb2cf29]
# genre                                           [Drama]
# average_rating                                     7.24
# ...                                                 ...
# собственник                                           0
# таможенный                                            0
# диабет                                                0
# млрд                                                  0
# рф                                                    0
#
#                                                            144  \
# age_access_type                                             16
# name                                          Медвежий поцелуй
# director                [3d64928e-b4a3-4c78-b176-77ef1045d5bc]
# genre            [Drama, 9fa28b61-a257-4a3e-945b-a9ef76a146d6]
# average_rating                                            7.43
# ...                                                        ...
# собственник                                                  0
# таможенный                                                   0
# диабет                                                       0
# млрд                                                         0
# рф                                                           0
#
#                                                     182  \
# age_access_type                                      16
# name                                           Байконур
# director         [1f007e2b-31c6-4f3d-849c-95a1df635ab1]
# genre                                [Melodrama, Drama]
# average_rating                                     6.09
# ...                                                 ...
# собственник                                           0
# таможенный                                            0
# диабет                                                0
# млрд                                                  0
# рф                                                    0
#
#                                                     199  \
# age_access_type                                      16
# name                                   Девушка и смерть
# director         [2b043c71-af5a-47b1-9755-432047883465]
# genre                                           [Drama]
# average_rating                                      6.8
# ...                                                 ...
# собственник                                           0
# таможенный                                            0
# диабет                                                0
# млрд                                                  0
# рф                                                    0
#
#                                                     230
# age_access_type                                      18
# name                                           Хрусталь
# director         [8468f32f-5484-46bc-9106-61149fb31ba4]
# genre                                   [Comedy, Drama]
# average_rating                                     7.05
# ...                                                 ...
# собственник                                           0
# таможенный                                            0
# диабет                                                0
# млрд                                                  0
# рф                                                    0
#
# [33859 rows x 5 columns]

# %%
russ_content.shape
# Out:
# (1705, 33859)

# %%
russ_content['release_year'].value_counts().sort_index()
# Out:
# 1953      1
# 1990      1
# 1992      7
# 1993      7
# 1994      3
# 1995      4
# 1996      1
# 1997      5
# 1998      4
# 1999      6
# 2000     14
# 2001     11
# 2002     13
# 2003     10
# 2004     33
# 2005     37
# 2006     51
# 2007     69
# 2008     68
# 2009     69
# 2010     62
# 2011     70
# 2012     95
# 2013     88
# 2014    109
# 2015    111
# 2016     91
# 2017     98
# 2018    127
# 2019    136
# 2020    116
# 2021    137
# 2022     51
# Name: release_year, dtype: int64

# %%
import pickle

with open('Okko_ratings_RUSS_FULL_kws.pkl', 'wb') as f:
    pickle.dump(russ_content, f)

# %% [markdown]
# ## Get foriegn content

# %%
foreign_content = df_merged[df_merged['element_id'].isin(list(russ_content['element_id'].values)) == False]

# %%
foreign_content.shape
# Out:
# (8784, 33859)

# %%
foreign_content.head().T
# Out:
#                                                       0  \
# age_access_type                                      12
# name                   Звёздный путь 5: Последний рубеж
# director         [cff3362f-ad91-498d-80b3-ea3ab8ec65cf]
# genre             [Sci-Fi, Action, Thriller, Adventure]
# average_rating                                     6.21
# ...                                                 ...
# собственник                                           0
# таможенный                                            0
# диабет                                                0
# млрд                                                  0
# рф                                                    0
#
#                                                       1  \
# age_access_type                                      16
# name                 Звёздный путь 6: Неоткрытая страна
# director         [bab6b7f4-4506-458f-9091-d567505674f2]
# genre             [Sci-Fi, Action, Thriller, Adventure]
# average_rating                                      7.2
# ...                                                 ...
# собственник                                           0
# таможенный                                            0
# диабет                                                0
# млрд                                                  0
# рф                                                    0
#
#                                                       2  \
# age_access_type                                      18
# name                       В поисках древнего артефакта
# director         [895f5774-964a-4c5a-ae22-d697d3e3e620]
# genre                                          [Horror]
# average_rating                                      4.0
# ...                                                 ...
# собственник                                           0
# таможенный                                            0
# диабет                                                0
# млрд                                                  0
# рф                                                    0
#
#                                                       3  \
# age_access_type                                      18
# name                                Прожарка Чарли Шина
# director         [1de22aff-430e-4af9-bf1d-159dbf8e9269]
# genre                             [Comedy, Documentary]
# average_rating                                     6.99
# ...                                                 ...
# собственник                                           0
# таможенный                                            0
# диабет                                                0
# млрд                                                  0
# рф                                                    0
#
#                                                                  4
# age_access_type                                                  6
# name                                              Пламенное сердце
# director         [40f78e6d-3c9f-434f-a505-c6ffdd045763, 332105c...
# genre            [Comedy, Adventure, Family, 287a1485-7a88-4c2f...
# average_rating                                                 6.4
# ...                                                            ...
# собственник                                                      0
# таможенный                                                       0
# диабет                                                           0
# млрд                                                             0
# рф                                                               0
#
# [33859 rows x 5 columns]

# %%
foreign_content['release_year'].value_counts().sort_index()
# Out:
# 1914      1
# 1915      1
# 1916      1
# 1919      1
# 1920      3
#        ...
# 2018    567
# 2019    696
# 2020    583
# 2021    417
# 2022    101
# Name: release_year, Length: 104, dtype: int64

# %%
import pickle

with open('Okko_ratings_FOREIGN_FULL_kws.pkl', 'wb') as f:
    pickle.dump(foreign_content, f)
